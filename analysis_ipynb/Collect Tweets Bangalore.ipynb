# %%
import tweepy
from tweepy import OAuthHandler
import json
import datetime as dt
import time
import os
import sys

# %%
def load_api():
    ''' Function that loads the twitter API after authorizing the user. '''

    consumer_key = 'HwzDzjGc6Bag4bG4EwYtS3WmR'
    consumer_secret = 'COCXfk8JRK8WJ2w5g5ALI181PkxVZyyOtA7FfTEqsPdH9d2Wrz'
    access_token = '1083597947239944192-8h8tKHeNoMyfKJQPWUggIE3SR3Gs4a'
    access_secret = 'u2onxF2pRwNLxdxCBMDlpGXCfmqoeE5qHokwuhwEFS9pS'
    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_secret)
    # load the twitter API via tweepy
    return tweepy.API(auth)

# %%
def tweet_search(api, max_tweets, max_id, since_id, geocode):
    ''' Function that takes in a search string 'query', the maximum
        number of tweets 'max_tweets', and the minimum (i.e., starting)
        tweet id. It returns a list of tweepy.models.Status objects. '''

    searched_tweets = []
    while len(searched_tweets) < max_tweets:
        remaining_tweets = max_tweets - len(searched_tweets)
        try:
            new_tweets = api.search(q="", count=remaining_tweets, since_id=str(since_id),max_id=str(max_id-1),geocode=geocode,tweet_mode='extended')
            print('found',len(new_tweets),'tweets')
            if not new_tweets:
                print('no tweets found')
                break
            searched_tweets.extend(new_tweets)
            max_id = new_tweets[-1].id
        except tweepy.TweepError:
            print('exception raised, waiting 15 minutes')
            print('(until:', dt.datetime.now()+dt.timedelta(minutes=15), ')')
            time.sleep(15*60)
            break # stop the loop
    return searched_tweets, max_id

# %%
def get_tweet_id(api, date='', days_ago=9, query='a'):
    ''' Function that gets the ID of a tweet. This ID can then be
        used as a 'starting point' from which to search. The query is
        required and has been set to a commonly used word by default.
        The variable 'days_ago' has been initialized to the maximum
        amount we are able to search back in time (9).'''

    if date:
        # return an ID from the start of the given day
        td = date + dt.timedelta(days=1)
        tweet_date = '{0}-{1:0>2}-{2:0>2}'.format(td.year, td.month, td.day)
        tweet = api.search(q=query, count=1, until=tweet_date)
    else:
        # return an ID from __ days ago
        td = dt.datetime.now() - dt.timedelta(days=days_ago)
        tweet_date = '{0}-{1:0>2}-{2:0>2}'.format(td.year, td.month, td.day)
        # get list of up to 10 tweets
        tweet = api.search(q=query, count=10, until=tweet_date)
        print('search limit (start/stop):',tweet[0].created_at)
        # return the id of the first tweet in the list
    return tweet[0].id

# %%
def write_tweets(tweets, filename):
    ''' Function that appends tweets to a file. '''

    with open(filename, 'a') as f:
        for tweet in tweets:
            json.dump(tweet._json, f)
            f.write('\n')

# %%
time_limit = 8                           # runtime limit in hours
max_tweets = 100                           # number of tweets per search (will be
                                               # iterated over) - maximum is 100
min_days_old, max_days_old = 8, 9          # search limits e.g., from 7 to 8
                                               # gives current weekday from last week,
                                               # min_days_old=0 will search from right now
Bangalore = '12.977405,77.574234,50km'       # this geocode includes Delhi area
                                              
    

    # loop over search items,
    # creating a new file for each
    #for search_phrase in search_phrases:

     #   print('Search phrase =', search_phrase)

      #  ''' other variables '''
      #  name = search_phrase.split()[0]
      #  json_file_root = name + '/'  + name
       # os.makedirs(os.path.dirname(json_file_root), exist_ok=True)
read_IDs = False
        
        # open a file in which to store the tweets
if max_days_old - min_days_old == 1:
    d = dt.datetime.now() - dt.timedelta(days=min_days_old)
    day = '{0}-{1:0>2}-{2:0>2}'.format(d.year, d.month, d.day)
else:
    d1 = dt.datetime.now() - dt.timedelta(days=max_days_old-1)
    d2 = dt.datetime.now() - dt.timedelta(days=min_days_old)
    day = '{0}-{1:0>2}-{2:0>2}_to_{3}-{4:0>2}-{5:0>2}'.format(d1.year, d1.month, d1.day, d2.year, d2.month, d2.day)
json_file = 'Bangalore' + '_' + day + '.json'
if os.path.isfile(json_file):
    print('Appending tweets to file named: ',json_file)
    read_IDs = True
        
        # authorize and load the twitter API
api = load_api()
        
        # set the 'starting point' ID for tweet collection
if read_IDs:
    # open the json file and get the latest tweet ID
    with open(json_file, 'r') as f:
        lines = f.readlines()
        max_id = json.loads(lines[-1])['id']
        print('Searching from the bottom ID in file')
else:
    # get the ID of a tweet that is min_days_old
    if min_days_old == 0:
        max_id = -1
    else:
        max_id = get_tweet_id(api, days_ago=(min_days_old-1))
    # set the smallest ID to search for
since_id = get_tweet_id(api, days_ago=(max_days_old-1))
print('max id (starting point) =', max_id)
print('since id (ending point) =', since_id)
        


''' tweet gathering loop  '''
start = dt.datetime.now()
end = start + dt.timedelta(hours=time_limit)
count, exitcount = 0, 0
while dt.datetime.now() < end:
    count += 1
    print('count =',count)
    # collect tweets and update max_id
    tweets, max_id = tweet_search(api, max_tweets,max_id=max_id, since_id=since_id,
                                          geocode=Bangalore)
            # write tweets to file in JSON format
    if tweets:
        write_tweets(tweets, json_file)
        exitcount = 0
    else:
        exitcount += 1
        if exitcount == 3:
            print('Maximum number of empty tweet strings reached - breaking')
            break
# Out:
# search limit (start/stop): 2019-03-20 23:59:59
# search limit (start/stop): 2019-03-19 23:59:59
# max id (starting point) = 1108518582466605056
# since id (ending point) = 1108156194600955904
# count = 1
# found 88 tweets
# found 9 tweets
# found 1 tweets
# found 2 tweets
# count = 2
# found 88 tweets
# found 9 tweets
# found 2 tweets
# found 1 tweets
# count = 3
# found 74 tweets
# found 20 tweets
# found 4 tweets
# found 0 tweets
# no tweets found
# count = 4
# found 86 tweets
# found 14 tweets
# count = 5
# found 87 tweets
# found 11 tweets
# found 1 tweets
# found 1 tweets
# count = 6
# found 55 tweets
# found 41 tweets
# found 4 tweets
# count = 7
# found 76 tweets
# found 20 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 8
# found 76 tweets
# found 23 tweets
# found 1 tweets
# count = 9
# found 91 tweets
# found 8 tweets
# found 1 tweets
# count = 10
# found 85 tweets
# found 4 tweets
# found 6 tweets
# found 1 tweets
# found 3 tweets
# found 1 tweets
# count = 11
# found 79 tweets
# found 18 tweets
# found 1 tweets
# found 1 tweets
# found 1 tweets
# count = 12
# found 92 tweets
# found 4 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 13
# found 86 tweets
# found 14 tweets
# count = 14
# found 77 tweets
# found 20 tweets
# found 2 tweets
# found 1 tweets
# count = 15
# found 79 tweets
# found 15 tweets
# found 2 tweets
# found 1 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 16
# found 47 tweets
# found 37 tweets
# found 16 tweets
# count = 17
# found 78 tweets
# found 19 tweets
# found 3 tweets
# count = 18
# found 87 tweets
# found 11 tweets
# found 2 tweets
# count = 19
# found 86 tweets
# found 10 tweets
# found 1 tweets
# found 1 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 20
# found 79 tweets
# found 16 tweets
# found 4 tweets
# found 1 tweets
# count = 21
# found 89 tweets
# found 10 tweets
# found 1 tweets
# count = 22
# found 82 tweets
# found 14 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 23
# found 82 tweets
# found 14 tweets
# found 3 tweets
# found 1 tweets
# count = 24
# found 84 tweets
# found 11 tweets
# found 2 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 25
# found 86 tweets
# found 8 tweets
# found 2 tweets
# found 1 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 26
# found 84 tweets
# found 12 tweets
# found 4 tweets
# count = 27
# found 85 tweets
# found 15 tweets
# count = 28
# found 80 tweets
# found 10 tweets
# found 8 tweets
# found 2 tweets
# count = 29
# found 73 tweets
# found 22 tweets
# found 5 tweets
# count = 30
# found 85 tweets
# found 11 tweets
# found 3 tweets
# found 1 tweets
# count = 31
# found 89 tweets
# found 11 tweets
# count = 32
# found 91 tweets
# found 8 tweets
# found 0 tweets
# no tweets found
# count = 33
# found 83 tweets
# found 14 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 34
# found 87 tweets
# found 7 tweets
# found 2 tweets
# found 1 tweets
# found 1 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 35
# found 80 tweets
# found 18 tweets
# found 2 tweets
# count = 36
# found 87 tweets
# found 11 tweets
# found 2 tweets
# count = 37
# found 79 tweets
# found 14 tweets
# found 5 tweets
# found 2 tweets
# count = 38
# found 80 tweets
# found 17 tweets
# found 1 tweets
# found 1 tweets
# found 1 tweets
# count = 39
# found 80 tweets
# found 16 tweets
# found 3 tweets
# found 1 tweets
# count = 40
# found 80 tweets
# found 16 tweets
# found 0 tweets
# no tweets found
# count = 41
# found 79 tweets
# found 15 tweets
# found 5 tweets
# found 1 tweets
# count = 42
# found 87 tweets
# found 10 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 43
# found 87 tweets
# found 11 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 44
# found 79 tweets
# found 18 tweets
# found 2 tweets
# found 1 tweets
# count = 45
# found 90 tweets
# found 8 tweets
# found 2 tweets
# count = 46
# found 86 tweets
# found 8 tweets
# found 3 tweets
# found 1 tweets
# found 2 tweets
# count = 47
# found 77 tweets
# exception raised, waiting 15 minutes
# (until: 2019-03-28 10:09:50.459312 )
# count = 48
# found 89 tweets
# found 10 tweets
# found 0 tweets
# no tweets found
# count = 49
# found 86 tweets
# found 8 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 50
# found 85 tweets
# found 8 tweets
# found 4 tweets
# found 1 tweets
# found 2 tweets
# count = 51
# found 86 tweets
# found 14 tweets
# count = 52
# found 98 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 53
# found 78 tweets
# found 18 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 54
# found 83 tweets
# found 16 tweets
# found 0 tweets
# no tweets found
# count = 55
# found 87 tweets
# found 9 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 56
# found 94 tweets
# found 6 tweets
# count = 57
# found 93 tweets
# found 6 tweets
# found 0 tweets
# no tweets found
# count = 58
# found 88 tweets
# found 8 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 59
# found 90 tweets
# found 6 tweets
# found 4 tweets
# count = 60
# found 94 tweets
# found 6 tweets
# count = 61
# found 80 tweets
# found 13 tweets
# found 6 tweets
# found 1 tweets
# count = 62
# found 87 tweets
# found 13 tweets
# count = 63
# found 86 tweets
# found 10 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 64
# found 90 tweets
# found 6 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 65
# found 77 tweets
# found 18 tweets
# found 5 tweets
# count = 66
# found 86 tweets
# found 14 tweets
# count = 67
# found 74 tweets
# found 25 tweets
# found 1 tweets
# count = 68
# found 86 tweets
# found 13 tweets
# found 0 tweets
# no tweets found
# count = 69
# found 88 tweets
# found 10 tweets
# found 1 tweets
# found 1 tweets
# count = 70
# found 96 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 71
# found 86 tweets
# found 14 tweets
# count = 72
# found 84 tweets
# found 12 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 73
# found 81 tweets
# found 15 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 74
# found 93 tweets
# found 6 tweets
# found 1 tweets
# count = 75
# found 91 tweets
# found 7 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 76
# found 85 tweets
# found 12 tweets
# found 1 tweets
# found 2 tweets
# count = 77
# found 86 tweets
# found 13 tweets
# found 1 tweets
# count = 78
# found 83 tweets
# found 10 tweets
# found 6 tweets
# found 0 tweets
# no tweets found
# count = 79
# found 95 tweets
# found 5 tweets
# count = 80
# found 90 tweets
# found 9 tweets
# found 0 tweets
# no tweets found
# count = 81
# found 98 tweets
# found 2 tweets
# count = 82
# found 81 tweets
# found 15 tweets
# found 1 tweets
# found 1 tweets
# found 2 tweets
# count = 83
# found 81 tweets
# found 16 tweets
# found 2 tweets
# found 1 tweets
# count = 84
# found 82 tweets
# found 16 tweets
# found 2 tweets
# count = 85
# found 84 tweets
# found 15 tweets
# found 1 tweets
# count = 86
# found 83 tweets
# found 17 tweets
# count = 87
# found 85 tweets
# found 13 tweets
# found 2 tweets
# count = 88
# found 89 tweets
# found 8 tweets
# found 1 tweets
# found 1 tweets
# found 1 tweets
# count = 89
# found 74 tweets
# found 20 tweets
# found 6 tweets
# count = 90
# found 91 tweets
# found 8 tweets
# found 0 tweets
# no tweets found
# count = 91
# found 82 tweets
# found 14 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 92
# found 82 tweets
# found 14 tweets
# found 1 tweets
# found 3 tweets
# count = 93
# found 78 tweets
# found 17 tweets
# found 4 tweets
# found 1 tweets
# count = 94
# found 90 tweets
# found 10 tweets
# count = 95
# found 91 tweets
# found 7 tweets
# found 2 tweets
# count = 96
# found 83 tweets
# found 11 tweets
# found 4 tweets
# found 0 tweets
# no tweets found
# count = 97
# found 79 tweets
# found 20 tweets
# found 1 tweets
# count = 98
# found 86 tweets
# found 12 tweets
# found 2 tweets
# count = 99
# found 85 tweets
# found 12 tweets
# found 3 tweets
# count = 100
# found 91 tweets
# found 8 tweets
# found 1 tweets
# count = 101
# found 85 tweets
# found 14 tweets
# found 0 tweets
# no tweets found
# count = 102
# found 85 tweets
# found 11 tweets
# found 1 tweets
# found 1 tweets
# exception raised, waiting 15 minutes
# (until: 2019-03-28 10:26:45.055957 )
# count = 103
# found 82 tweets
# found 14 tweets
# found 4 tweets
# count = 104
# found 91 tweets
# found 8 tweets
# found 1 tweets
# count = 105
# found 77 tweets
# found 17 tweets
# found 5 tweets
# found 0 tweets
# no tweets found
# count = 106
# found 87 tweets
# found 7 tweets
# found 3 tweets
# found 3 tweets
# count = 107
# found 90 tweets
# found 9 tweets
# found 0 tweets
# no tweets found
# count = 108
# found 85 tweets
# found 13 tweets
# found 0 tweets
# no tweets found
# count = 109
# found 87 tweets
# found 8 tweets
# found 5 tweets
# count = 110
# found 86 tweets
# found 11 tweets
# found 1 tweets
# found 2 tweets
# count = 111
# found 86 tweets
# found 8 tweets
# found 4 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 112
# found 91 tweets
# found 8 tweets
# found 1 tweets
# count = 113
# found 94 tweets
# found 4 tweets
# found 0 tweets
# no tweets found
# count = 114
# found 87 tweets
# found 12 tweets
# found 1 tweets
# count = 115
# found 90 tweets
# found 7 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 116
# found 88 tweets
# found 10 tweets
# found 2 tweets
# count = 117
# found 84 tweets
# found 15 tweets
# found 0 tweets
# no tweets found
# count = 118
# found 84 tweets
# found 12 tweets
# found 1 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 119
# found 89 tweets
# found 9 tweets
# found 2 tweets
# count = 120
# found 90 tweets
# found 6 tweets
# found 2 tweets
# found 1 tweets
# found 1 tweets
# count = 121
# found 86 tweets
# found 10 tweets
# found 2 tweets
# found 1 tweets
# found 1 tweets
# count = 122
# found 80 tweets
# found 19 tweets
# found 0 tweets
# no tweets found
# count = 123
# found 93 tweets
# found 6 tweets
# found 0 tweets
# no tweets found
# count = 124
# found 92 tweets
# found 4 tweets
# found 3 tweets
# found 1 tweets
# count = 125
# found 82 tweets
# found 15 tweets
# found 3 tweets
# count = 126
# found 88 tweets
# found 10 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 127
# found 88 tweets
# found 11 tweets
# found 0 tweets
# no tweets found
# count = 128
# found 83 tweets
# found 17 tweets
# count = 129
# found 88 tweets
# found 11 tweets
# found 1 tweets
# count = 130
# found 87 tweets
# found 7 tweets
# found 4 tweets
# found 2 tweets
# count = 131
# found 90 tweets
# found 10 tweets
# count = 132
# found 84 tweets
# found 16 tweets
# count = 133
# found 81 tweets
# found 15 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 134
# found 79 tweets
# found 14 tweets
# found 4 tweets
# found 3 tweets
# count = 135
# found 86 tweets
# found 14 tweets
# count = 136
# found 91 tweets
# found 9 tweets
# count = 137
# found 88 tweets
# found 8 tweets
# found 0 tweets
# no tweets found
# count = 138
# found 79 tweets
# found 17 tweets
# found 1 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 139
# found 81 tweets
# found 13 tweets
# found 4 tweets
# found 0 tweets
# no tweets found
# count = 140
# found 84 tweets
# found 15 tweets
# found 1 tweets
# count = 141
# found 78 tweets
# found 17 tweets
# found 5 tweets
# count = 142
# found 89 tweets
# found 9 tweets
# found 2 tweets
# count = 143
# found 80 tweets
# found 15 tweets
# found 3 tweets
# found 1 tweets
# found 1 tweets
# count = 144
# found 88 tweets
# found 10 tweets
# found 2 tweets
# count = 145
# found 94 tweets
# found 6 tweets
# count = 146
# found 95 tweets
# found 4 tweets
# found 1 tweets
# count = 147
# found 92 tweets
# found 5 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 148
# found 91 tweets
# found 7 tweets
# found 0 tweets
# no tweets found
# count = 149
# found 84 tweets
# found 16 tweets
# count = 150
# found 90 tweets
# found 8 tweets
# found 2 tweets
# count = 151
# found 92 tweets
# found 7 tweets
# found 0 tweets
# no tweets found
# count = 152
# found 85 tweets
# found 9 tweets
# found 4 tweets
# found 0 tweets
# no tweets found
# count = 153
# found 83 tweets
# found 11 tweets
# found 5 tweets
# found 1 tweets
# count = 154
# found 90 tweets
# found 9 tweets
# found 1 tweets
# count = 155
# found 94 tweets
# found 5 tweets
# found 1 tweets
# count = 156
# found 88 tweets
# found 9 tweets
# found 3 tweets
# count = 157
# exception raised, waiting 15 minutes
# (until: 2019-03-28 10:43:55.205338 )
# count = 158
# found 84 tweets
# found 13 tweets
# found 3 tweets
# count = 159
# found 84 tweets
# found 7 tweets
# found 5 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 160
# found 71 tweets
# found 23 tweets
# found 6 tweets
# count = 161
# found 84 tweets
# found 9 tweets
# found 6 tweets
# found 1 tweets
# count = 162
# found 72 tweets
# found 22 tweets
# found 4 tweets
# found 2 tweets
# count = 163
# found 83 tweets
# found 13 tweets
# found 3 tweets
# found 1 tweets
# count = 164
# found 74 tweets
# found 23 tweets
# found 3 tweets
# count = 165
# found 80 tweets
# found 18 tweets
# found 2 tweets
# count = 166
# found 95 tweets
# found 5 tweets
# count = 167
# found 88 tweets
# found 10 tweets
# found 1 tweets
# found 1 tweets
# count = 168
# found 92 tweets
# found 5 tweets
# found 2 tweets
# found 1 tweets
# count = 169
# found 79 tweets
# found 21 tweets
# count = 170
# found 90 tweets
# found 8 tweets
# found 0 tweets
# no tweets found
# count = 171
# found 82 tweets
# found 13 tweets
# found 5 tweets
# count = 172
# found 92 tweets
# found 8 tweets
# count = 173
# found 91 tweets
# found 7 tweets
# found 1 tweets
# found 1 tweets
# count = 174
# found 85 tweets
# found 12 tweets
# found 3 tweets
# count = 175
# found 90 tweets
# found 10 tweets
# count = 176
# found 95 tweets
# found 5 tweets
# count = 177
# found 94 tweets
# found 6 tweets
# count = 178
# found 99 tweets
# found 1 tweets
# count = 179
# found 95 tweets
# found 5 tweets
# count = 180
# found 93 tweets
# found 6 tweets
# found 0 tweets
# no tweets found
# count = 181
# found 87 tweets
# found 12 tweets
# found 0 tweets
# no tweets found
# count = 182
# found 96 tweets
# found 2 tweets
# found 1 tweets
# found 1 tweets
# count = 183
# found 91 tweets
# found 5 tweets
# found 3 tweets
# found 1 tweets
# count = 184
# found 88 tweets
# found 7 tweets
# found 4 tweets
# found 1 tweets
# count = 185
# found 88 tweets
# found 6 tweets
# found 2 tweets
# found 1 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 186
# found 91 tweets
# found 7 tweets
# found 2 tweets
# count = 187
# found 95 tweets
# found 5 tweets
# count = 188
# found 98 tweets
# found 0 tweets
# no tweets found
# count = 189
# found 88 tweets
# found 10 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 190
# found 85 tweets
# found 15 tweets
# count = 191
# found 90 tweets
# found 9 tweets
# found 1 tweets
# count = 192
# found 100 tweets
# count = 193
# found 86 tweets
# found 12 tweets
# found 1 tweets
# found 1 tweets
# count = 194
# found 93 tweets
# found 6 tweets
# found 1 tweets
# count = 195
# found 85 tweets
# found 10 tweets
# found 3 tweets
# found 1 tweets
# found 1 tweets
# count = 196
# found 87 tweets
# found 8 tweets
# found 5 tweets
# count = 197
# found 91 tweets
# found 5 tweets
# found 1 tweets
# found 1 tweets
# found 2 tweets
# count = 198
# found 100 tweets
# count = 199
# found 95 tweets
# found 4 tweets
# found 1 tweets
# count = 200
# found 96 tweets
# found 2 tweets
# found 2 tweets
# count = 201
# found 96 tweets
# found 2 tweets
# found 2 tweets
# count = 202
# found 89 tweets
# found 10 tweets
# found 0 tweets
# no tweets found
# count = 203
# found 79 tweets
# found 18 tweets
# found 3 tweets
# count = 204
# found 96 tweets
# found 4 tweets
# count = 205
# found 91 tweets
# found 9 tweets
# count = 206
# found 89 tweets
# found 10 tweets
# found 1 tweets
# count = 207
# found 90 tweets
# found 8 tweets
# found 1 tweets
# found 1 tweets
# count = 208
# found 96 tweets
# found 1 tweets
# found 1 tweets
# found 2 tweets
# count = 209
# found 71 tweets
# found 22 tweets
# found 6 tweets
# found 0 tweets
# no tweets found
# count = 210
# found 84 tweets
# found 14 tweets
# found 2 tweets
# count = 211
# found 94 tweets
# found 5 tweets
# found 1 tweets
# count = 212
# found 100 tweets
# count = 213
# found 93 tweets
# found 6 tweets
# found 1 tweets
# count = 214
# found 89 tweets
# found 11 tweets
# count = 215
# found 88 tweets
# found 8 tweets
# found 4 tweets
# count = 216
# found 90 tweets
# found 10 tweets
# count = 217
# found 91 tweets
# exception raised, waiting 15 minutes
# (until: 2019-03-28 11:00:50.947370 )
# count = 218
# found 85 tweets
# found 14 tweets
# found 1 tweets
# count = 219
# found 84 tweets
# found 15 tweets
# found 0 tweets
# no tweets found
# count = 220
# found 88 tweets
# found 10 tweets
# found 0 tweets
# no tweets found
# count = 221
# found 89 tweets
# found 9 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 222
# found 90 tweets
# found 8 tweets
# found 2 tweets
# count = 223
# found 87 tweets
# found 9 tweets
# found 2 tweets
# found 1 tweets
# found 1 tweets
# count = 224
# found 90 tweets
# found 10 tweets
# count = 225
# found 91 tweets
# found 8 tweets
# found 1 tweets
# count = 226
# found 91 tweets
# found 9 tweets
# count = 227
# found 98 tweets
# found 2 tweets
# count = 228
# found 85 tweets
# found 15 tweets
# count = 229
# found 94 tweets
# found 6 tweets
# count = 230
# found 86 tweets
# found 14 tweets
# count = 231
# found 80 tweets
# found 18 tweets
# found 2 tweets
# count = 232
# found 86 tweets
# found 10 tweets
# found 2 tweets
# found 2 tweets
# count = 233
# found 100 tweets
# count = 234
# found 91 tweets
# found 9 tweets
# count = 235
# found 78 tweets
# found 22 tweets
# count = 236
# found 79 tweets
# found 18 tweets
# found 3 tweets
# count = 237
# found 82 tweets
# found 16 tweets
# found 1 tweets
# found 1 tweets
# count = 238
# found 97 tweets
# found 3 tweets
# count = 239
# found 90 tweets
# found 9 tweets
# found 1 tweets
# count = 240
# found 91 tweets
# found 7 tweets
# found 2 tweets
# count = 241
# found 92 tweets
# found 7 tweets
# found 1 tweets
# count = 242
# found 93 tweets
# found 4 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 243
# found 81 tweets
# found 19 tweets
# count = 244
# found 81 tweets
# found 16 tweets
# found 3 tweets
# count = 245
# found 89 tweets
# found 8 tweets
# found 1 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 246
# found 91 tweets
# found 7 tweets
# found 2 tweets
# count = 247
# found 96 tweets
# found 2 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 248
# found 82 tweets
# found 14 tweets
# found 3 tweets
# found 1 tweets
# count = 249
# found 88 tweets
# found 12 tweets
# count = 250
# found 84 tweets
# found 13 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 251
# found 75 tweets
# found 21 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 252
# found 69 tweets
# found 26 tweets
# found 4 tweets
# found 0 tweets
# no tweets found
# count = 253
# found 83 tweets
# found 15 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 254
# found 91 tweets
# found 6 tweets
# found 3 tweets
# count = 255
# found 95 tweets
# found 5 tweets
# count = 256
# found 86 tweets
# found 13 tweets
# found 1 tweets
# count = 257
# found 78 tweets
# found 16 tweets
# found 6 tweets
# count = 258
# found 80 tweets
# found 16 tweets
# found 2 tweets
# found 1 tweets
# found 1 tweets
# count = 259
# found 77 tweets
# found 18 tweets
# found 4 tweets
# found 1 tweets
# count = 260
# found 83 tweets
# found 16 tweets
# found 1 tweets
# count = 261
# found 73 tweets
# found 20 tweets
# found 7 tweets
# count = 262
# found 90 tweets
# found 10 tweets
# count = 263
# found 89 tweets
# found 9 tweets
# found 1 tweets
# found 1 tweets
# count = 264
# found 93 tweets
# found 5 tweets
# found 2 tweets
# count = 265
# found 81 tweets
# found 13 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 266
# found 86 tweets
# found 10 tweets
# found 3 tweets
# found 1 tweets
# count = 267
# found 83 tweets
# found 10 tweets
# found 5 tweets
# found 1 tweets
# found 1 tweets
# count = 268
# found 83 tweets
# found 17 tweets
# count = 269
# found 87 tweets
# found 11 tweets
# found 1 tweets
# found 1 tweets
# count = 270
# found 81 tweets
# found 15 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 271
# found 77 tweets
# found 19 tweets
# found 3 tweets
# found 1 tweets
# count = 272
# found 88 tweets
# found 10 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 273
# found 73 tweets
# found 24 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 274
# found 82 tweets
# exception raised, waiting 15 minutes
# (until: 2019-03-28 11:17:55.690638 )
# count = 275
# found 91 tweets
# found 7 tweets
# found 0 tweets
# no tweets found
# count = 276
# found 85 tweets
# found 13 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 277
# found 96 tweets
# found 2 tweets
# found 2 tweets
# count = 278
# found 89 tweets
# found 9 tweets
# found 1 tweets
# found 1 tweets
# count = 279
# found 89 tweets
# found 10 tweets
# found 0 tweets
# no tweets found
# count = 280
# found 81 tweets
# found 16 tweets
# found 0 tweets
# no tweets found
# count = 281
# found 88 tweets
# found 10 tweets
# found 2 tweets
# count = 282
# found 85 tweets
# found 12 tweets
# found 3 tweets
# count = 283
# found 88 tweets
# found 8 tweets
# found 0 tweets
# no tweets found
# count = 284
# found 72 tweets
# found 26 tweets
# found 2 tweets
# count = 285
# found 97 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 286
# found 84 tweets
# found 15 tweets
# found 0 tweets
# no tweets found
# count = 287
# found 86 tweets
# found 14 tweets
# count = 288
# found 92 tweets
# found 7 tweets
# found 1 tweets
# count = 289
# found 90 tweets
# found 10 tweets
# count = 290
# found 79 tweets
# found 20 tweets
# found 1 tweets
# count = 291
# found 83 tweets
# found 15 tweets
# found 2 tweets
# count = 292
# found 91 tweets
# found 9 tweets
# count = 293
# found 80 tweets
# found 16 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 294
# found 88 tweets
# found 9 tweets
# found 2 tweets
# found 1 tweets
# count = 295
# found 83 tweets
# found 17 tweets
# count = 296
# found 94 tweets
# found 5 tweets
# found 1 tweets
# count = 297
# found 88 tweets
# found 7 tweets
# found 5 tweets
# count = 298
# found 82 tweets
# found 18 tweets
# count = 299
# found 87 tweets
# found 11 tweets
# found 2 tweets
# count = 300
# found 75 tweets
# found 18 tweets
# found 6 tweets
# found 0 tweets
# no tweets found
# count = 301
# found 87 tweets
# found 8 tweets
# found 4 tweets
# found 0 tweets
# no tweets found
# count = 302
# found 93 tweets
# found 4 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 303
# found 86 tweets
# found 10 tweets
# found 2 tweets
# found 2 tweets
# count = 304
# found 87 tweets
# found 13 tweets
# count = 305
# found 89 tweets
# found 8 tweets
# found 0 tweets
# no tweets found
# count = 306
# found 90 tweets
# found 10 tweets
# count = 307
# found 80 tweets
# found 17 tweets
# found 2 tweets
# found 1 tweets
# count = 308
# found 93 tweets
# found 5 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 309
# found 82 tweets
# found 17 tweets
# found 1 tweets
# count = 310
# found 89 tweets
# found 7 tweets
# found 3 tweets
# found 1 tweets
# count = 311
# found 85 tweets
# found 14 tweets
# found 1 tweets
# count = 312
# found 88 tweets
# found 11 tweets
# found 1 tweets
# count = 313
# found 98 tweets
# found 2 tweets
# count = 314
# found 88 tweets
# found 9 tweets
# found 1 tweets
# found 2 tweets
# count = 315
# found 86 tweets
# found 13 tweets
# found 1 tweets
# count = 316
# found 90 tweets
# found 8 tweets
# found 1 tweets
# found 1 tweets
# count = 317
# found 81 tweets
# found 15 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 318
# found 95 tweets
# found 4 tweets
# found 1 tweets
# count = 319
# found 89 tweets
# found 8 tweets
# found 0 tweets
# no tweets found
# count = 320
# found 78 tweets
# found 19 tweets
# found 1 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 321
# found 88 tweets
# found 12 tweets
# count = 322
# found 93 tweets
# found 7 tweets
# count = 323
# found 91 tweets
# found 8 tweets
# found 1 tweets
# count = 324
# found 90 tweets
# found 9 tweets
# found 1 tweets
# count = 325
# found 92 tweets
# found 5 tweets
# found 3 tweets
# count = 326
# found 87 tweets
# found 7 tweets
# found 4 tweets
# found 1 tweets
# found 1 tweets
# count = 327
# found 85 tweets
# found 13 tweets
# found 2 tweets
# count = 328
# found 96 tweets
# found 2 tweets
# found 2 tweets
# count = 329
# found 86 tweets
# found 13 tweets
# found 1 tweets
# count = 330
# found 91 tweets
# found 7 tweets
# found 2 tweets
# count = 331
# found 88 tweets
# found 6 tweets
# found 6 tweets
# count = 332
# found 84 tweets
# exception raised, waiting 15 minutes
# (until: 2019-03-28 11:34:59.046451 )
# count = 333
# found 94 tweets
# found 6 tweets
# count = 334
# found 93 tweets
# found 6 tweets
# found 0 tweets
# no tweets found
# count = 335
# found 88 tweets
# found 8 tweets
# found 4 tweets
# count = 336
# found 90 tweets
# found 8 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 337
# found 92 tweets
# found 6 tweets
# found 1 tweets
# found 1 tweets
# count = 338
# found 93 tweets
# found 5 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 339
# found 100 tweets
# count = 340
# found 100 tweets
# count = 341
# found 99 tweets
# found 1 tweets
# count = 342
# found 100 tweets
# count = 343
# found 98 tweets
# found 2 tweets
# count = 344
# found 98 tweets
# found 0 tweets
# no tweets found
# count = 345
# found 93 tweets
# found 7 tweets
# count = 346
# found 96 tweets
# found 3 tweets
# found 1 tweets
# count = 347
# found 92 tweets
# found 7 tweets
# found 1 tweets
# count = 348
# found 90 tweets
# found 10 tweets
# count = 349
# found 98 tweets
# found 1 tweets
# found 1 tweets
# count = 350
# found 85 tweets
# found 14 tweets
# found 1 tweets
# count = 351
# found 81 tweets
# found 16 tweets
# found 2 tweets
# found 1 tweets
# count = 352
# found 91 tweets
# found 6 tweets
# found 0 tweets
# no tweets found
# count = 353
# found 85 tweets
# found 11 tweets
# found 1 tweets
# found 1 tweets
# found 1 tweets
# found 1 tweets
# count = 354
# found 89 tweets
# found 11 tweets
# count = 355
# found 90 tweets
# found 8 tweets
# found 0 tweets
# no tweets found
# count = 356
# found 87 tweets
# found 10 tweets
# found 1 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 357
# found 95 tweets
# found 4 tweets
# found 1 tweets
# count = 358
# found 92 tweets
# found 7 tweets
# found 1 tweets
# count = 359
# found 92 tweets
# found 8 tweets
# count = 360
# found 97 tweets
# found 1 tweets
# found 2 tweets
# count = 361
# found 93 tweets
# found 4 tweets
# found 3 tweets
# count = 362
# found 82 tweets
# found 18 tweets
# count = 363
# found 94 tweets
# found 5 tweets
# found 0 tweets
# no tweets found
# count = 364
# found 81 tweets
# found 14 tweets
# found 5 tweets
# count = 365
# found 82 tweets
# found 14 tweets
# found 4 tweets
# count = 366
# found 89 tweets
# found 4 tweets
# found 6 tweets
# found 0 tweets
# no tweets found
# count = 367
# found 89 tweets
# found 6 tweets
# found 3 tweets
# found 1 tweets
# found 1 tweets
# count = 368
# found 81 tweets
# found 15 tweets
# found 4 tweets
# count = 369
# found 91 tweets
# found 9 tweets
# count = 370
# found 90 tweets
# found 8 tweets
# found 0 tweets
# no tweets found
# count = 371
# found 89 tweets
# found 9 tweets
# found 1 tweets
# found 1 tweets
# count = 372
# found 89 tweets
# found 11 tweets
# count = 373
# found 96 tweets
# found 4 tweets
# count = 374
# found 86 tweets
# found 14 tweets
# count = 375
# found 88 tweets
# found 8 tweets
# found 1 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 376
# found 85 tweets
# found 13 tweets
# found 1 tweets
# found 1 tweets
# count = 377
# found 82 tweets
# found 12 tweets
# found 5 tweets
# found 1 tweets
# count = 378
# found 92 tweets
# found 8 tweets
# count = 379
# found 81 tweets
# found 14 tweets
# found 5 tweets
# count = 380
# found 83 tweets
# found 13 tweets
# found 3 tweets
# found 1 tweets
# count = 381
# found 71 tweets
# found 27 tweets
# found 2 tweets
# count = 382
# found 77 tweets
# found 19 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 383
# found 79 tweets
# found 18 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 384
# found 91 tweets
# found 5 tweets
# found 1 tweets
# found 2 tweets
# found 1 tweets
# count = 385
# found 77 tweets
# found 19 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 386
# found 88 tweets
# found 12 tweets
# count = 387
# found 89 tweets
# found 9 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 388
# found 86 tweets
# found 13 tweets
# found 1 tweets
# count = 389
# found 84 tweets
# found 12 tweets
# found 3 tweets
# found 1 tweets
# count = 390
# found 91 tweets
# found 8 tweets
# found 0 tweets
# no tweets found
# count = 391
# found 89 tweets
# found 11 tweets
# count = 392
# exception raised, waiting 15 minutes
# (until: 2019-03-28 11:52:01.437031 )
# count = 393
# found 94 tweets
# found 6 tweets
# count = 394
# found 91 tweets
# found 7 tweets
# found 2 tweets
# count = 395
# found 95 tweets
# found 4 tweets
# found 1 tweets
# count = 396
# found 99 tweets
# found 0 tweets
# no tweets found
# count = 397
# found 91 tweets
# found 8 tweets
# found 1 tweets
# count = 398
# found 100 tweets
# count = 399
# found 82 tweets
# found 18 tweets
# count = 400
# found 100 tweets
# count = 401
# found 87 tweets
# found 13 tweets
# count = 402
# found 88 tweets
# found 12 tweets
# count = 403
# found 87 tweets
# found 11 tweets
# found 1 tweets
# found 1 tweets
# count = 404
# found 91 tweets
# found 9 tweets
# count = 405
# found 97 tweets
# found 1 tweets
# found 2 tweets
# count = 406
# found 77 tweets
# found 19 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 407
# found 93 tweets
# found 3 tweets
# found 1 tweets
# found 3 tweets
# count = 408
# found 84 tweets
# found 13 tweets
# found 2 tweets
# found 1 tweets
# count = 409
# found 75 tweets
# found 15 tweets
# found 8 tweets
# found 1 tweets
# found 1 tweets
# count = 410
# found 84 tweets
# found 9 tweets
# found 7 tweets
# count = 411
# found 72 tweets
# found 17 tweets
# found 9 tweets
# found 2 tweets
# count = 412
# found 91 tweets
# found 6 tweets
# found 2 tweets
# found 1 tweets
# count = 413
# found 78 tweets
# found 16 tweets
# found 3 tweets
# found 3 tweets
# count = 414
# found 90 tweets
# found 7 tweets
# found 2 tweets
# found 1 tweets
# count = 415
# found 83 tweets
# found 17 tweets
# count = 416
# found 79 tweets
# found 21 tweets
# count = 417
# found 85 tweets
# found 14 tweets
# found 0 tweets
# no tweets found
# count = 418
# found 91 tweets
# found 8 tweets
# found 1 tweets
# count = 419
# found 98 tweets
# found 2 tweets
# count = 420
# found 92 tweets
# found 8 tweets
# count = 421
# found 80 tweets
# found 17 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 422
# found 78 tweets
# found 21 tweets
# found 0 tweets
# no tweets found
# count = 423
# found 83 tweets
# found 14 tweets
# found 3 tweets
# count = 424
# found 87 tweets
# found 10 tweets
# found 2 tweets
# found 1 tweets
# count = 425
# found 99 tweets
# found 0 tweets
# no tweets found
# count = 426
# found 92 tweets
# found 7 tweets
# found 1 tweets
# count = 427
# found 88 tweets
# found 6 tweets
# found 6 tweets
# count = 428
# found 91 tweets
# found 7 tweets
# found 1 tweets
# found 1 tweets
# count = 429
# found 94 tweets
# found 5 tweets
# found 0 tweets
# no tweets found
# count = 430
# found 93 tweets
# found 7 tweets
# count = 431
# found 100 tweets
# count = 432
# found 93 tweets
# found 7 tweets
# count = 433
# found 88 tweets
# found 12 tweets
# count = 434
# found 94 tweets
# found 6 tweets
# count = 435
# found 91 tweets
# found 8 tweets
# found 1 tweets
# count = 436
# found 84 tweets
# found 10 tweets
# found 3 tweets
# found 2 tweets
# found 1 tweets
# count = 437
# found 84 tweets
# found 13 tweets
# found 0 tweets
# no tweets found
# count = 438
# found 89 tweets
# found 9 tweets
# found 2 tweets
# count = 439
# found 97 tweets
# found 3 tweets
# count = 440
# found 86 tweets
# found 12 tweets
# found 2 tweets
# count = 441
# found 79 tweets
# found 15 tweets
# found 4 tweets
# found 2 tweets
# count = 442
# found 91 tweets
# found 9 tweets
# count = 443
# found 94 tweets
# found 6 tweets
# count = 444
# found 93 tweets
# found 6 tweets
# found 0 tweets
# no tweets found
# count = 445
# found 86 tweets
# found 13 tweets
# found 1 tweets
# count = 446
# found 85 tweets
# found 11 tweets
# found 4 tweets
# count = 447
# found 83 tweets
# found 15 tweets
# found 2 tweets
# count = 448
# found 82 tweets
# found 15 tweets
# found 1 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 449
# found 85 tweets
# found 12 tweets
# found 3 tweets
# count = 450
# found 87 tweets
# found 12 tweets
# found 1 tweets
# count = 451
# found 97 tweets
# found 2 tweets
# found 1 tweets
# count = 452
# found 93 tweets
# found 6 tweets
# found 1 tweets
# count = 453
# found 93 tweets
# found 7 tweets
# count = 454
# found 86 tweets
# found 10 tweets
# found 3 tweets
# found 1 tweets
# count = 455
# exception raised, waiting 15 minutes
# (until: 2019-03-28 12:09:08.750434 )
# count = 456
# found 90 tweets
# found 9 tweets
# found 1 tweets
# count = 457
# found 87 tweets
# found 4 tweets
# found 3 tweets
# found 2 tweets
# found 4 tweets
# count = 458
# found 86 tweets
# found 13 tweets
# found 0 tweets
# no tweets found
# count = 459
# found 93 tweets
# found 5 tweets
# found 2 tweets
# count = 460
# found 80 tweets
# found 14 tweets
# found 5 tweets
# found 0 tweets
# no tweets found
# count = 461
# found 93 tweets
# found 7 tweets
# count = 462
# found 85 tweets
# found 10 tweets
# found 5 tweets
# count = 463
# found 94 tweets
# found 4 tweets
# found 2 tweets
# count = 464
# found 91 tweets
# found 7 tweets
# found 1 tweets
# found 1 tweets
# count = 465
# found 87 tweets
# found 8 tweets
# found 2 tweets
# found 1 tweets
# found 2 tweets
# count = 466
# found 94 tweets
# found 4 tweets
# found 2 tweets
# count = 467
# found 94 tweets
# found 5 tweets
# found 1 tweets
# count = 468
# found 91 tweets
# found 9 tweets
# count = 469
# found 81 tweets
# found 15 tweets
# found 2 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 470
# found 91 tweets
# found 8 tweets
# found 1 tweets
# count = 471
# found 95 tweets
# found 5 tweets
# count = 472
# found 88 tweets
# found 10 tweets
# found 2 tweets
# count = 473
# found 82 tweets
# found 16 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 474
# found 90 tweets
# found 7 tweets
# found 2 tweets
# found 1 tweets
# count = 475
# found 90 tweets
# found 9 tweets
# found 1 tweets
# count = 476
# found 98 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 477
# found 94 tweets
# found 6 tweets
# count = 478
# found 95 tweets
# found 5 tweets
# count = 479
# found 98 tweets
# found 2 tweets
# count = 480
# found 92 tweets
# found 6 tweets
# found 2 tweets
# count = 481
# found 94 tweets
# found 6 tweets
# count = 482
# found 100 tweets
# count = 483
# found 92 tweets
# found 8 tweets
# count = 484
# found 96 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 485
# found 88 tweets
# found 10 tweets
# found 1 tweets
# found 1 tweets
# count = 486
# found 88 tweets
# found 10 tweets
# found 1 tweets
# found 1 tweets
# count = 487
# found 87 tweets
# found 13 tweets
# count = 488
# found 95 tweets
# found 4 tweets
# found 0 tweets
# no tweets found
# count = 489
# found 99 tweets
# found 1 tweets
# count = 490
# found 92 tweets
# found 8 tweets
# count = 491
# found 87 tweets
# found 12 tweets
# found 1 tweets
# count = 492
# found 93 tweets
# found 6 tweets
# found 1 tweets
# count = 493
# found 92 tweets
# found 5 tweets
# found 2 tweets
# found 1 tweets
# count = 494
# found 88 tweets
# found 10 tweets
# found 1 tweets
# found 1 tweets
# count = 495
# found 80 tweets
# found 13 tweets
# found 7 tweets
# count = 496
# found 86 tweets
# found 11 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 497
# found 92 tweets
# found 5 tweets
# found 2 tweets
# found 1 tweets
# count = 498
# found 90 tweets
# found 9 tweets
# found 1 tweets
# count = 499
# found 86 tweets
# found 13 tweets
# found 0 tweets
# no tweets found
# count = 500
# found 86 tweets
# found 8 tweets
# found 3 tweets
# found 2 tweets
# found 1 tweets
# count = 501
# found 84 tweets
# found 14 tweets
# found 2 tweets
# count = 502
# found 80 tweets
# found 16 tweets
# found 3 tweets
# found 1 tweets
# count = 503
# found 90 tweets
# found 10 tweets
# count = 504
# found 96 tweets
# found 2 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 505
# found 87 tweets
# found 8 tweets
# found 3 tweets
# found 2 tweets
# count = 506
# found 84 tweets
# found 12 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 507
# found 81 tweets
# found 18 tweets
# found 1 tweets
# count = 508
# found 90 tweets
# found 9 tweets
# found 0 tweets
# no tweets found
# count = 509
# found 100 tweets
# count = 510
# found 77 tweets
# found 18 tweets
# found 3 tweets
# found 2 tweets
# count = 511
# found 87 tweets
# found 11 tweets
# found 2 tweets
# count = 512
# found 92 tweets
# found 8 tweets
# count = 513
# found 81 tweets
# found 19 tweets
# count = 514
# found 91 tweets
# exception raised, waiting 15 minutes
# (until: 2019-03-28 12:26:19.160916 )
# count = 515
# found 81 tweets
# found 16 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 516
# found 92 tweets
# found 8 tweets
# count = 517
# found 81 tweets
# found 15 tweets
# found 2 tweets
# found 1 tweets
# found 1 tweets
# count = 518
# found 82 tweets
# found 13 tweets
# found 5 tweets
# count = 519
# found 84 tweets
# found 16 tweets
# count = 520
# found 86 tweets
# found 13 tweets
# found 1 tweets
# count = 521
# found 91 tweets
# found 8 tweets
# found 0 tweets
# no tweets found
# count = 522
# found 91 tweets
# found 8 tweets
# found 1 tweets
# count = 523
# found 87 tweets
# found 12 tweets
# found 0 tweets
# no tweets found
# count = 524
# found 88 tweets
# found 8 tweets
# found 1 tweets
# found 2 tweets
# found 1 tweets
# count = 525
# found 89 tweets
# found 11 tweets
# count = 526
# found 92 tweets
# found 8 tweets
# count = 527
# found 100 tweets
# count = 528
# found 89 tweets
# found 11 tweets
# count = 529
# found 95 tweets
# found 5 tweets
# count = 530
# found 100 tweets
# count = 531
# found 85 tweets
# found 15 tweets
# count = 532
# found 93 tweets
# found 6 tweets
# found 0 tweets
# no tweets found
# count = 533
# found 89 tweets
# found 11 tweets
# count = 534
# found 88 tweets
# found 8 tweets
# found 3 tweets
# found 1 tweets
# count = 535
# found 91 tweets
# found 5 tweets
# found 2 tweets
# found 2 tweets
# count = 536
# found 87 tweets
# found 11 tweets
# found 0 tweets
# no tweets found
# count = 537
# found 94 tweets
# found 5 tweets
# found 0 tweets
# no tweets found
# count = 538
# found 97 tweets
# found 3 tweets
# count = 539
# found 97 tweets
# found 3 tweets
# count = 540
# found 98 tweets
# found 2 tweets
# count = 541
# found 90 tweets
# found 6 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 542
# found 87 tweets
# found 10 tweets
# found 2 tweets
# found 1 tweets
# count = 543
# found 98 tweets
# found 0 tweets
# no tweets found
# count = 544
# found 96 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 545
# found 91 tweets
# found 8 tweets
# found 1 tweets
# count = 546
# found 100 tweets
# count = 547
# found 100 tweets
# count = 548
# found 100 tweets
# count = 549
# found 96 tweets
# found 4 tweets
# count = 550
# found 96 tweets
# found 4 tweets
# count = 551
# found 100 tweets
# count = 552
# found 100 tweets
# count = 553
# found 96 tweets
# found 3 tweets
# found 1 tweets
# count = 554
# found 100 tweets
# count = 555
# found 100 tweets
# count = 556
# found 94 tweets
# found 5 tweets
# found 1 tweets
# count = 557
# found 99 tweets
# found 0 tweets
# no tweets found
# count = 558
# found 93 tweets
# found 7 tweets
# count = 559
# found 84 tweets
# found 13 tweets
# found 3 tweets
# count = 560
# found 86 tweets
# found 12 tweets
# found 2 tweets
# count = 561
# found 87 tweets
# found 12 tweets
# found 1 tweets
# count = 562
# found 85 tweets
# found 14 tweets
# found 0 tweets
# no tweets found
# count = 563
# found 87 tweets
# found 8 tweets
# found 4 tweets
# found 1 tweets
# count = 564
# found 87 tweets
# found 10 tweets
# found 1 tweets
# found 2 tweets
# count = 565
# found 90 tweets
# found 9 tweets
# found 0 tweets
# no tweets found
# count = 566
# found 90 tweets
# found 7 tweets
# found 0 tweets
# no tweets found
# count = 567
# found 73 tweets
# found 24 tweets
# found 3 tweets
# count = 568
# found 83 tweets
# found 11 tweets
# found 5 tweets
# found 1 tweets
# count = 569
# found 86 tweets
# found 13 tweets
# found 0 tweets
# no tweets found
# count = 570
# found 91 tweets
# found 6 tweets
# found 0 tweets
# no tweets found
# count = 571
# found 88 tweets
# found 8 tweets
# found 2 tweets
# found 1 tweets
# found 1 tweets
# count = 572
# found 86 tweets
# found 11 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 573
# found 83 tweets
# found 13 tweets
# found 4 tweets
# count = 574
# found 93 tweets
# found 6 tweets
# found 0 tweets
# no tweets found
# count = 575
# found 97 tweets
# found 3 tweets
# count = 576
# found 91 tweets
# found 6 tweets
# found 1 tweets
# found 2 tweets
# count = 577
# found 81 tweets
# found 17 tweets
# found 1 tweets
# found 1 tweets
# count = 578
# found 97 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 579
# found 96 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 580
# found 88 tweets
# found 12 tweets
# count = 581
# found 88 tweets
# exception raised, waiting 15 minutes
# (until: 2019-03-28 12:43:32.066781 )
# count = 582
# found 94 tweets
# found 6 tweets
# count = 583
# found 100 tweets
# count = 584
# found 95 tweets
# found 5 tweets
# count = 585
# found 79 tweets
# found 20 tweets
# found 1 tweets
# count = 586
# found 94 tweets
# found 6 tweets
# count = 587
# found 96 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 588
# found 91 tweets
# found 6 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 589
# found 84 tweets
# found 16 tweets
# count = 590
# found 96 tweets
# found 4 tweets
# count = 591
# found 98 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 592
# found 83 tweets
# found 13 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 593
# found 90 tweets
# found 6 tweets
# found 3 tweets
# found 1 tweets
# count = 594
# found 85 tweets
# found 13 tweets
# found 2 tweets
# count = 595
# found 87 tweets
# found 7 tweets
# found 6 tweets
# count = 596
# found 86 tweets
# found 12 tweets
# found 2 tweets
# count = 597
# found 87 tweets
# found 10 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 598
# found 83 tweets
# found 15 tweets
# found 2 tweets
# count = 599
# found 89 tweets
# found 10 tweets
# found 0 tweets
# no tweets found
# count = 600
# found 86 tweets
# found 13 tweets
# found 1 tweets
# count = 601
# found 89 tweets
# found 7 tweets
# found 3 tweets
# found 1 tweets
# count = 602
# found 86 tweets
# found 11 tweets
# found 2 tweets
# found 1 tweets
# count = 603
# found 99 tweets
# found 1 tweets
# count = 604
# found 94 tweets
# found 5 tweets
# found 1 tweets
# count = 605
# found 82 tweets
# found 15 tweets
# found 2 tweets
# found 1 tweets
# count = 606
# found 91 tweets
# found 8 tweets
# found 1 tweets
# count = 607
# found 86 tweets
# found 13 tweets
# found 0 tweets
# no tweets found
# count = 608
# found 90 tweets
# found 8 tweets
# found 1 tweets
# found 1 tweets
# count = 609
# found 92 tweets
# found 6 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 610
# found 89 tweets
# found 10 tweets
# found 1 tweets
# count = 611
# found 90 tweets
# found 10 tweets
# count = 612
# found 88 tweets
# found 11 tweets
# found 1 tweets
# count = 613
# found 88 tweets
# found 12 tweets
# count = 614
# found 90 tweets
# found 6 tweets
# found 1 tweets
# found 1 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 615
# found 89 tweets
# found 11 tweets
# count = 616
# found 94 tweets
# found 6 tweets
# count = 617
# found 92 tweets
# found 8 tweets
# count = 618
# found 85 tweets
# found 15 tweets
# count = 619
# found 81 tweets
# found 17 tweets
# found 2 tweets
# count = 620
# found 90 tweets
# found 9 tweets
# found 0 tweets
# no tweets found
# count = 621
# found 83 tweets
# found 14 tweets
# found 2 tweets
# found 1 tweets
# count = 622
# found 84 tweets
# found 10 tweets
# found 3 tweets
# found 3 tweets
# count = 623
# found 96 tweets
# found 4 tweets
# count = 624
# found 88 tweets
# found 9 tweets
# found 0 tweets
# no tweets found
# count = 625
# found 87 tweets
# found 11 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 626
# found 83 tweets
# found 12 tweets
# found 4 tweets
# found 0 tweets
# no tweets found
# count = 627
# found 86 tweets
# found 12 tweets
# found 0 tweets
# no tweets found
# count = 628
# found 87 tweets
# found 10 tweets
# found 2 tweets
# found 1 tweets
# count = 629
# found 94 tweets
# found 6 tweets
# count = 630
# found 95 tweets
# found 3 tweets
# found 2 tweets
# count = 631
# found 90 tweets
# found 7 tweets
# found 2 tweets
# found 1 tweets
# count = 632
# found 91 tweets
# found 8 tweets
# found 1 tweets
# count = 633
# found 84 tweets
# found 13 tweets
# found 0 tweets
# no tweets found
# count = 634
# found 87 tweets
# found 10 tweets
# found 2 tweets
# found 1 tweets
# count = 635
# found 88 tweets
# found 11 tweets
# found 1 tweets
# count = 636
# found 73 tweets
# found 24 tweets
# found 3 tweets
# count = 637
# found 79 tweets
# found 19 tweets
# found 2 tweets
# count = 638
# found 93 tweets
# found 6 tweets
# found 0 tweets
# no tweets found
# count = 639
# found 88 tweets
# found 10 tweets
# found 0 tweets
# no tweets found
# count = 640
# found 84 tweets
# found 14 tweets
# found 2 tweets
# count = 641
# exception raised, waiting 15 minutes
# (until: 2019-03-28 13:00:40.610629 )
# count = 642
# found 83 tweets
# found 13 tweets
# found 2 tweets
# found 1 tweets
# found 1 tweets
# count = 643
# found 93 tweets
# found 5 tweets
# found 1 tweets
# found 1 tweets
# count = 644
# found 83 tweets
# found 14 tweets
# found 3 tweets
# count = 645
# found 88 tweets
# found 11 tweets
# found 1 tweets
# count = 646
# exception raised, waiting 15 minutes
# (until: 2019-03-28 13:15:50.557715 )
# count = 647
# found 93 tweets
# found 7 tweets
# count = 648
# found 90 tweets
# found 10 tweets
# count = 649
# found 86 tweets
# found 11 tweets
# found 3 tweets
# count = 650
# found 91 tweets
# found 6 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 651
# found 89 tweets
# found 10 tweets
# found 1 tweets
# count = 652
# found 83 tweets
# found 15 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 653
# found 90 tweets
# found 10 tweets
# count = 654
# found 84 tweets
# found 11 tweets
# found 3 tweets
# found 2 tweets
# count = 655
# found 85 tweets
# found 12 tweets
# found 1 tweets
# found 2 tweets
# count = 656
# found 84 tweets
# found 14 tweets
# found 2 tweets
# count = 657
# found 87 tweets
# found 9 tweets
# found 0 tweets
# no tweets found
# count = 658
# found 82 tweets
# found 15 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 659
# found 81 tweets
# found 15 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 660
# found 87 tweets
# found 11 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 661
# found 79 tweets
# found 19 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 662
# found 86 tweets
# found 13 tweets
# found 1 tweets
# count = 663
# found 96 tweets
# found 2 tweets
# found 2 tweets
# count = 664
# found 90 tweets
# found 6 tweets
# found 3 tweets
# found 1 tweets
# count = 665
# found 85 tweets
# found 15 tweets
# count = 666
# found 91 tweets
# found 4 tweets
# found 4 tweets
# found 1 tweets
# count = 667
# found 86 tweets
# found 14 tweets
# count = 668
# found 100 tweets
# count = 669
# found 87 tweets
# found 11 tweets
# found 2 tweets
# count = 670
# found 89 tweets
# found 9 tweets
# found 2 tweets
# count = 671
# found 100 tweets
# count = 672
# found 98 tweets
# found 2 tweets
# count = 673
# found 91 tweets
# found 5 tweets
# found 1 tweets
# found 1 tweets
# found 1 tweets
# found 1 tweets
# count = 674
# found 85 tweets
# found 15 tweets
# count = 675
# found 82 tweets
# found 16 tweets
# found 2 tweets
# count = 676
# found 82 tweets
# found 16 tweets
# found 2 tweets
# count = 677
# found 79 tweets
# found 16 tweets
# found 4 tweets
# found 1 tweets
# count = 678
# found 90 tweets
# found 10 tweets
# count = 679
# found 89 tweets
# found 9 tweets
# found 1 tweets
# found 1 tweets
# count = 680
# found 86 tweets
# found 11 tweets
# found 2 tweets
# found 1 tweets
# count = 681
# found 92 tweets
# found 6 tweets
# found 2 tweets
# count = 682
# found 87 tweets
# found 12 tweets
# found 1 tweets
# count = 683
# found 86 tweets
# found 13 tweets
# found 1 tweets
# count = 684
# found 94 tweets
# found 4 tweets
# found 1 tweets
# found 1 tweets
# count = 685
# found 96 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 686
# found 89 tweets
# found 10 tweets
# found 1 tweets
# count = 687
# found 89 tweets
# found 10 tweets
# found 0 tweets
# no tweets found
# count = 688
# found 88 tweets
# found 12 tweets
# count = 689
# found 83 tweets
# found 11 tweets
# found 6 tweets
# count = 690
# found 91 tweets
# found 5 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 691
# found 85 tweets
# found 13 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 692
# found 79 tweets
# found 17 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 693
# found 84 tweets
# found 12 tweets
# found 2 tweets
# found 2 tweets
# count = 694
# found 78 tweets
# found 22 tweets
# count = 695
# found 81 tweets
# found 15 tweets
# found 1 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 696
# found 84 tweets
# found 11 tweets
# found 4 tweets
# found 1 tweets
# count = 697
# found 88 tweets
# found 8 tweets
# found 3 tweets
# found 1 tweets
# count = 698
# found 80 tweets
# found 19 tweets
# found 1 tweets
# count = 699
# found 90 tweets
# found 6 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 700
# found 91 tweets
# found 7 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 701
# found 91 tweets
# found 8 tweets
# found 1 tweets
# count = 702
# found 86 tweets
# found 14 tweets
# count = 703
# exception raised, waiting 15 minutes
# (until: 2019-03-28 13:33:14.338693 )
# count = 704
# found 83 tweets
# found 11 tweets
# found 1 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 705
# found 83 tweets
# found 13 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 706
# found 82 tweets
# found 17 tweets
# found 1 tweets
# count = 707
# found 85 tweets
# found 15 tweets
# count = 708
# found 85 tweets
# found 13 tweets
# found 2 tweets
# count = 709
# found 91 tweets
# found 8 tweets
# found 1 tweets
# count = 710
# found 81 tweets
# found 17 tweets
# found 2 tweets
# count = 711
# found 86 tweets
# found 12 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 712
# found 83 tweets
# found 16 tweets
# found 0 tweets
# no tweets found
# count = 713
# found 91 tweets
# found 9 tweets
# count = 714
# found 91 tweets
# found 5 tweets
# found 1 tweets
# found 1 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 715
# found 74 tweets
# found 23 tweets
# found 3 tweets
# count = 716
# found 91 tweets
# found 9 tweets
# count = 717
# found 90 tweets
# found 6 tweets
# found 2 tweets
# found 2 tweets
# count = 718
# found 77 tweets
# found 17 tweets
# found 4 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 719
# found 82 tweets
# found 13 tweets
# found 3 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 720
# found 87 tweets
# found 11 tweets
# found 2 tweets
# count = 721
# found 78 tweets
# found 20 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 722
# found 81 tweets
# found 16 tweets
# found 2 tweets
# found 1 tweets
# count = 723
# found 90 tweets
# found 6 tweets
# found 3 tweets
# found 1 tweets
# count = 724
# found 98 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 725
# found 98 tweets
# found 1 tweets
# found 1 tweets
# count = 726
# found 95 tweets
# found 5 tweets
# count = 727
# found 86 tweets
# found 12 tweets
# found 2 tweets
# count = 728
# found 100 tweets
# count = 729
# found 95 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 730
# found 91 tweets
# found 6 tweets
# found 1 tweets
# found 2 tweets
# count = 731
# found 91 tweets
# ...
# found 2 tweets
# found 2 tweets
# count = 821
# found 83 tweets
# found 17 tweets
# count = 822
# found 90 tweets
# found 9 tweets
# found 1 tweets
# count = 823
# found 99 tweets
# found 1 tweets
# count = 824
# found 89 tweets
# found 8 tweets
# found 3 tweets
# count = 825
# found 78 tweets
# found 22 tweets
# count = 826
# found 87 tweets
# found 11 tweets
# found 2 tweets
# count = 827
# found 80 tweets
# found 17 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 828
# found 79 tweets
# found 15 tweets
# found 6 tweets
# count = 829
# found 83 tweets
# found 13 tweets
# found 2 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 830
# found 80 tweets
# found 15 tweets
# found 5 tweets
# count = 831
# found 82 tweets
# found 14 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 832
# found 83 tweets
# found 15 tweets
# found 0 tweets
# no tweets found
# count = 833
# found 90 tweets
# found 8 tweets
# found 1 tweets
# found 1 tweets
# count = 834
# found 94 tweets
# found 4 tweets
# found 2 tweets
# count = 835
# found 95 tweets
# found 5 tweets
# count = 836
# found 85 tweets
# found 15 tweets
# count = 837
# found 85 tweets
# found 11 tweets
# found 2 tweets
# found 2 tweets
# count = 838
# found 95 tweets
# found 4 tweets
# found 1 tweets
# count = 839
# found 100 tweets
# count = 840
# found 99 tweets
# found 1 tweets
# count = 841
# found 91 tweets
# found 7 tweets
# found 1 tweets
# found 1 tweets
# count = 842
# found 84 tweets
# found 14 tweets
# found 1 tweets
# found 1 tweets
# count = 843
# found 90 tweets
# found 10 tweets
# count = 844
# found 82 tweets
# found 17 tweets
# found 1 tweets
# count = 845
# found 94 tweets
# found 6 tweets
# count = 846
# found 96 tweets
# found 4 tweets
# count = 847
# found 93 tweets
# found 5 tweets
# found 1 tweets
# found 1 tweets
# count = 848
# found 96 tweets
# found 3 tweets
# found 1 tweets
# count = 849
# found 97 tweets
# found 2 tweets
# found 1 tweets
# count = 850
# found 91 tweets
# found 8 tweets
# found 0 tweets
# no tweets found
# count = 851
# found 94 tweets
# found 5 tweets
# found 1 tweets
# count = 852
# found 94 tweets
# found 6 tweets
# count = 853
# found 97 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 854
# found 85 tweets
# found 12 tweets
# found 0 tweets
# no tweets found
# count = 855
# found 80 tweets
# found 19 tweets
# found 1 tweets
# count = 856
# found 91 tweets
# found 7 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 857
# found 88 tweets
# found 12 tweets
# count = 858
# found 87 tweets
# found 13 tweets
# count = 859
# found 84 tweets
# found 16 tweets
# count = 860
# found 94 tweets
# found 3 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 861
# found 95 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 862
# found 91 tweets
# found 6 tweets
# found 3 tweets
# count = 863
# found 95 tweets
# found 3 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 864
# found 93 tweets
# found 5 tweets
# found 0 tweets
# no tweets found
# count = 865
# found 94 tweets
# found 5 tweets
# found 0 tweets
# no tweets found
# count = 866
# found 85 tweets
# found 14 tweets
# found 1 tweets
# count = 867
# found 87 tweets
# found 10 tweets
# found 3 tweets
# count = 868
# found 87 tweets
# found 12 tweets
# found 0 tweets
# no tweets found
# count = 869
# found 88 tweets
# found 11 tweets
# found 0 tweets
# no tweets found
# count = 870
# found 90 tweets
# found 8 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 871
# found 93 tweets
# found 5 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 872
# found 86 tweets
# found 8 tweets
# found 4 tweets
# found 0 tweets
# no tweets found
# count = 873
# found 91 tweets
# found 9 tweets
# count = 874
# found 87 tweets
# found 11 tweets
# found 1 tweets
# exception raised, waiting 15 minutes
# (until: 2019-03-28 14:25:56.775794 )
# count = 875
# found 90 tweets
# found 8 tweets
# found 2 tweets
# count = 876
# found 81 tweets
# found 14 tweets
# found 2 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 877
# found 78 tweets
# found 17 tweets
# found 5 tweets
# count = 878
# found 90 tweets
# found 8 tweets
# found 0 tweets
# no tweets found
# count = 879
# found 94 tweets
# found 4 tweets
# found 0 tweets
# no tweets found
# count = 880
# found 99 tweets
# found 1 tweets
# count = 881
# found 92 tweets
# found 6 tweets
# found 1 tweets
# found 1 tweets
# count = 882
# found 100 tweets
# count = 883
# found 92 tweets
# found 7 tweets
# found 0 tweets
# no tweets found
# count = 884
# found 88 tweets
# found 11 tweets
# found 0 tweets
# no tweets found
# count = 885
# found 92 tweets
# found 7 tweets
# found 0 tweets
# no tweets found
# count = 886
# found 96 tweets
# found 3 tweets
# found 1 tweets
# count = 887
# found 95 tweets
# found 5 tweets
# count = 888
# found 92 tweets
# found 4 tweets
# found 4 tweets
# count = 889
# found 100 tweets
# count = 890
# found 100 tweets
# count = 891
# found 100 tweets
# count = 892
# found 92 tweets
# found 8 tweets
# count = 893
# found 96 tweets
# found 3 tweets
# found 1 tweets
# count = 894
# found 97 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 895
# found 87 tweets
# found 7 tweets
# found 1 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 896
# found 88 tweets
# found 9 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 897
# found 88 tweets
# found 9 tweets
# found 1 tweets
# found 1 tweets
# found 1 tweets
# count = 898
# found 100 tweets
# count = 899
# found 93 tweets
# found 6 tweets
# found 0 tweets
# no tweets found
# count = 900
# found 95 tweets
# found 5 tweets
# count = 901
# found 79 tweets
# found 17 tweets
# found 1 tweets
# found 1 tweets
# found 1 tweets
# found 1 tweets
# count = 902
# found 91 tweets
# found 8 tweets
# found 1 tweets
# count = 903
# found 83 tweets
# found 14 tweets
# found 2 tweets
# found 1 tweets
# count = 904
# found 87 tweets
# found 10 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 905
# found 86 tweets
# found 10 tweets
# found 1 tweets
# found 2 tweets
# found 1 tweets
# count = 906
# found 94 tweets
# found 5 tweets
# found 0 tweets
# no tweets found
# count = 907
# found 95 tweets
# found 3 tweets
# found 2 tweets
# count = 908
# found 93 tweets
# found 7 tweets
# count = 909
# found 92 tweets
# found 7 tweets
# found 1 tweets
# count = 910
# found 90 tweets
# found 9 tweets
# found 1 tweets
# count = 911
# found 91 tweets
# found 5 tweets
# found 3 tweets
# found 1 tweets
# count = 912
# found 86 tweets
# found 13 tweets
# found 0 tweets
# no tweets found
# count = 913
# found 84 tweets
# found 14 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 914
# found 91 tweets
# found 7 tweets
# found 1 tweets
# found 1 tweets
# count = 915
# found 77 tweets
# found 18 tweets
# found 4 tweets
# found 1 tweets
# count = 916
# found 87 tweets
# found 10 tweets
# found 0 tweets
# no tweets found
# count = 917
# found 74 tweets
# found 24 tweets
# found 1 tweets
# found 1 tweets
# count = 918
# found 87 tweets
# found 12 tweets
# found 1 tweets
# count = 919
# found 90 tweets
# found 8 tweets
# found 2 tweets
# count = 920
# found 89 tweets
# found 10 tweets
# found 1 tweets
# count = 921
# found 87 tweets
# found 9 tweets
# found 3 tweets
# found 1 tweets
# count = 922
# found 82 tweets
# found 11 tweets
# found 5 tweets
# found 1 tweets
# found 1 tweets
# count = 923
# found 91 tweets
# found 6 tweets
# found 3 tweets
# count = 924
# found 91 tweets
# found 8 tweets
# found 0 tweets
# no tweets found
# count = 925
# found 92 tweets
# found 7 tweets
# found 0 tweets
# no tweets found
# count = 926
# found 100 tweets
# count = 927
# found 95 tweets
# found 5 tweets
# count = 928
# found 87 tweets
# found 8 tweets
# found 5 tweets
# count = 929
# found 96 tweets
# found 4 tweets
# count = 930
# found 94 tweets
# found 4 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 931
# found 94 tweets
# found 5 tweets
# found 1 tweets
# count = 932
# found 88 tweets
# found 12 tweets
# count = 933
# found 81 tweets
# found 14 tweets
# exception raised, waiting 15 minutes
# (until: 2019-03-28 14:43:06.247248 )
# count = 934
# found 85 tweets
# found 12 tweets
# found 3 tweets
# count = 935
# found 83 tweets
# found 11 tweets
# found 5 tweets
# found 0 tweets
# no tweets found
# count = 936
# found 85 tweets
# found 14 tweets
# found 1 tweets
# count = 937
# found 77 tweets
# found 19 tweets
# found 4 tweets
# count = 938
# found 95 tweets
# found 4 tweets
# found 0 tweets
# no tweets found
# count = 939
# found 87 tweets
# found 10 tweets
# found 3 tweets
# count = 940
# found 92 tweets
# found 8 tweets
# count = 941
# found 94 tweets
# found 6 tweets
# count = 942
# found 98 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 943
# found 87 tweets
# found 9 tweets
# found 3 tweets
# found 1 tweets
# count = 944
# found 95 tweets
# found 5 tweets
# count = 945
# found 86 tweets
# found 9 tweets
# found 4 tweets
# found 1 tweets
# count = 946
# found 76 tweets
# found 14 tweets
# found 7 tweets
# found 2 tweets
# found 1 tweets
# count = 947
# found 74 tweets
# found 20 tweets
# found 4 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 948
# found 81 tweets
# found 15 tweets
# found 3 tweets
# found 1 tweets
# count = 949
# found 87 tweets
# found 10 tweets
# found 3 tweets
# count = 950
# found 85 tweets
# found 13 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 951
# found 100 tweets
# count = 952
# found 84 tweets
# found 9 tweets
# found 6 tweets
# found 1 tweets
# count = 953
# found 87 tweets
# found 13 tweets
# count = 954
# found 82 tweets
# found 14 tweets
# found 3 tweets
# found 1 tweets
# count = 955
# found 80 tweets
# found 18 tweets
# found 0 tweets
# no tweets found
# count = 956
# found 82 tweets
# found 16 tweets
# found 0 tweets
# no tweets found
# count = 957
# found 96 tweets
# found 4 tweets
# count = 958
# found 86 tweets
# found 11 tweets
# found 1 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 959
# found 89 tweets
# found 11 tweets
# count = 960
# found 95 tweets
# found 5 tweets
# count = 961
# found 92 tweets
# found 7 tweets
# found 0 tweets
# no tweets found
# count = 962
# found 85 tweets
# found 15 tweets
# count = 963
# found 93 tweets
# found 4 tweets
# found 2 tweets
# found 1 tweets
# count = 964
# found 86 tweets
# found 13 tweets
# found 0 tweets
# no tweets found
# count = 965
# found 91 tweets
# found 8 tweets
# found 1 tweets
# count = 966
# found 93 tweets
# found 7 tweets
# count = 967
# found 95 tweets
# found 4 tweets
# found 0 tweets
# no tweets found
# count = 968
# found 93 tweets
# found 6 tweets
# found 0 tweets
# no tweets found
# count = 969
# found 88 tweets
# found 10 tweets
# found 1 tweets
# found 1 tweets
# count = 970
# found 90 tweets
# found 10 tweets
# count = 971
# found 91 tweets
# found 7 tweets
# found 2 tweets
# count = 972
# found 92 tweets
# found 6 tweets
# found 2 tweets
# count = 973
# found 92 tweets
# found 8 tweets
# count = 974
# found 93 tweets
# found 5 tweets
# found 2 tweets
# count = 975
# found 92 tweets
# found 8 tweets
# count = 976
# found 89 tweets
# found 11 tweets
# count = 977
# found 88 tweets
# found 12 tweets
# count = 978
# found 88 tweets
# found 10 tweets
# found 2 tweets
# count = 979
# found 77 tweets
# found 18 tweets
# found 3 tweets
# found 1 tweets
# found 1 tweets
# count = 980
# found 90 tweets
# found 10 tweets
# count = 981
# found 97 tweets
# found 2 tweets
# found 1 tweets
# count = 982
# found 94 tweets
# found 2 tweets
# found 3 tweets
# found 1 tweets
# count = 983
# found 98 tweets
# found 1 tweets
# found 1 tweets
# count = 984
# found 88 tweets
# found 11 tweets
# found 1 tweets
# count = 985
# found 84 tweets
# found 13 tweets
# found 2 tweets
# found 1 tweets
# count = 986
# found 96 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 987
# found 79 tweets
# found 18 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 988
# found 87 tweets
# found 10 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 989
# found 91 tweets
# found 5 tweets
# found 4 tweets
# count = 990
# found 91 tweets
# found 9 tweets
# count = 991
# found 90 tweets
# found 10 tweets
# count = 992
# found 98 tweets
# found 0 tweets
# no tweets found
# count = 993
# found 92 tweets
# found 4 tweets
# exception raised, waiting 15 minutes
# (until: 2019-03-28 15:00:16.936141 )
# count = 994
# found 89 tweets
# found 10 tweets
# found 1 tweets
# count = 995
# found 87 tweets
# found 9 tweets
# found 2 tweets
# found 1 tweets
# found 1 tweets
# count = 996
# found 93 tweets
# found 7 tweets
# count = 997
# found 86 tweets
# found 12 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 998
# found 91 tweets
# found 9 tweets
# count = 999
# found 87 tweets
# found 10 tweets
# found 3 tweets
# count = 1000
# found 88 tweets
# found 10 tweets
# found 2 tweets
# count = 1001
# found 94 tweets
# found 5 tweets
# found 0 tweets
# no tweets found
# count = 1002
# found 90 tweets
# found 5 tweets
# found 5 tweets
# count = 1003
# found 81 tweets
# found 19 tweets
# count = 1004
# found 96 tweets
# found 4 tweets
# count = 1005
# found 85 tweets
# found 15 tweets
# count = 1006
# found 99 tweets
# found 1 tweets
# count = 1007
# found 96 tweets
# found 1 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 1008
# found 88 tweets
# found 9 tweets
# found 2 tweets
# found 1 tweets
# count = 1009
# found 90 tweets
# found 6 tweets
# found 4 tweets
# count = 1010
# found 85 tweets
# found 13 tweets
# found 2 tweets
# count = 1011
# found 100 tweets
# count = 1012
# found 91 tweets
# found 8 tweets
# found 1 tweets
# count = 1013
# found 92 tweets
# found 7 tweets
# found 1 tweets
# count = 1014
# found 91 tweets
# found 5 tweets
# found 4 tweets
# count = 1015
# found 93 tweets
# found 4 tweets
# found 2 tweets
# found 1 tweets
# count = 1016
# found 94 tweets
# found 6 tweets
# count = 1017
# found 97 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 1018
# found 81 tweets
# found 16 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 1019
# found 92 tweets
# found 6 tweets
# found 1 tweets
# found 1 tweets
# count = 1020
# found 92 tweets
# found 8 tweets
# count = 1021
# found 87 tweets
# found 13 tweets
# count = 1022
# found 91 tweets
# found 6 tweets
# found 2 tweets
# found 1 tweets
# count = 1023
# found 98 tweets
# found 2 tweets
# count = 1024
# found 95 tweets
# found 5 tweets
# count = 1025
# found 92 tweets
# found 8 tweets
# count = 1026
# found 91 tweets
# found 7 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 1027
# found 77 tweets
# found 18 tweets
# found 5 tweets
# count = 1028
# found 87 tweets
# found 9 tweets
# found 4 tweets
# count = 1029
# found 92 tweets
# found 5 tweets
# found 2 tweets
# found 1 tweets
# count = 1030
# found 84 tweets
# found 13 tweets
# found 2 tweets
# found 1 tweets
# count = 1031
# found 88 tweets
# found 11 tweets
# found 0 tweets
# no tweets found
# count = 1032
# found 79 tweets
# found 19 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 1033
# found 92 tweets
# found 7 tweets
# found 1 tweets
# count = 1034
# found 90 tweets
# found 10 tweets
# count = 1035
# found 86 tweets
# found 13 tweets
# found 1 tweets
# count = 1036
# found 95 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 1037
# found 85 tweets
# found 14 tweets
# found 0 tweets
# no tweets found
# count = 1038
# found 92 tweets
# found 7 tweets
# found 0 tweets
# no tweets found
# count = 1039
# found 83 tweets
# found 17 tweets
# count = 1040
# found 88 tweets
# found 12 tweets
# count = 1041
# found 85 tweets
# found 11 tweets
# found 4 tweets
# count = 1042
# found 67 tweets
# found 25 tweets
# found 6 tweets
# found 2 tweets
# count = 1043
# found 95 tweets
# found 5 tweets
# count = 1044
# found 97 tweets
# found 3 tweets
# count = 1045
# found 75 tweets
# found 21 tweets
# found 2 tweets
# found 1 tweets
# found 1 tweets
# count = 1046
# found 81 tweets
# found 13 tweets
# found 4 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 1047
# found 67 tweets
# found 26 tweets
# found 6 tweets
# found 1 tweets
# count = 1048
# found 86 tweets
# found 11 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 1049
# found 79 tweets
# found 14 tweets
# found 6 tweets
# found 0 tweets
# no tweets found
# count = 1050
# found 83 tweets
# found 14 tweets
# found 3 tweets
# count = 1051
# found 78 tweets
# found 16 tweets
# found 5 tweets
# found 1 tweets
# count = 1052
# found 95 tweets
# found 5 tweets
# count = 1053
# found 93 tweets
# exception raised, waiting 15 minutes
# (until: 2019-03-28 15:17:28.608886 )
# count = 1054
# found 94 tweets
# found 3 tweets
# found 3 tweets
# count = 1055
# found 71 tweets
# found 29 tweets
# count = 1056
# found 89 tweets
# found 5 tweets
# found 2 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 1057
# found 92 tweets
# found 5 tweets
# found 3 tweets
# count = 1058
# found 86 tweets
# found 11 tweets
# found 3 tweets
# count = 1059
# found 87 tweets
# found 12 tweets
# found 1 tweets
# count = 1060
# found 80 tweets
# found 20 tweets
# count = 1061
# found 90 tweets
# found 7 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 1062
# found 84 tweets
# found 13 tweets
# found 1 tweets
# found 2 tweets
# count = 1063
# found 92 tweets
# found 6 tweets
# found 2 tweets
# count = 1064
# found 62 tweets
# found 0 tweets
# no tweets found
# count = 1065
# found 0 tweets
# no tweets found
# count = 1066
# found 0 tweets
# no tweets found
# count = 1067
# found 0 tweets
# no tweets found
# Maximum number of empty tweet strings reached - breaking
