# %%
import tweepy
from tweepy import OAuthHandler
import json
import datetime as dt
import time
import os
import sys

# %%
def load_api():
    ''' Function that loads the twitter API after authorizing the user. '''

    consumer_key = ''
    consumer_secret = ''
    access_token = ''
    access_secret = ''
    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_secret)
    # load the twitter API via tweepy
    return tweepy.API(auth)

# %%
def tweet_search(api, max_tweets, max_id, since_id, geocode):
    ''' Function that takes in a search string 'query', the maximum
        number of tweets 'max_tweets', and the minimum (i.e., starting)
        tweet id. It returns a list of tweepy.models.Status objects. '''

    searched_tweets = []
    while len(searched_tweets) < max_tweets:
        remaining_tweets = max_tweets - len(searched_tweets)
        try:
            new_tweets = api.search(q="", count=remaining_tweets, since_id=str(since_id),max_id=str(max_id-1),geocode=geocode,tweet_mode='extended')
            print('found',len(new_tweets),'tweets')
            if not new_tweets:
                print('no tweets found')
                break
            searched_tweets.extend(new_tweets)
            max_id = new_tweets[-1].id
        except tweepy.TweepError:
            print('exception raised, waiting 15 minutes')
            print('(until:', dt.datetime.now()+dt.timedelta(minutes=15), ')')
            time.sleep(15*60)
            break # stop the loop
    return searched_tweets, max_id

# %%
def get_tweet_id(api, date='', days_ago=9, query='a'):
    ''' Function that gets the ID of a tweet. This ID can then be
        used as a 'starting point' from which to search. The query is
        required and has been set to a commonly used word by default.
        The variable 'days_ago' has been initialized to the maximum
        amount we are able to search back in time (9).'''

    if date:
        # return an ID from the start of the given day
        td = date + dt.timedelta(days=1)
        tweet_date = '{0}-{1:0>2}-{2:0>2}'.format(td.year, td.month, td.day)
        tweet = api.search(q=query, count=1, until=tweet_date)
    else:
        # return an ID from __ days ago
        td = dt.datetime.now() - dt.timedelta(days=days_ago)
        tweet_date = '{0}-{1:0>2}-{2:0>2}'.format(td.year, td.month, td.day)
        # get list of up to 10 tweets
        tweet = api.search(q=query, count=10, until=tweet_date)
        print('search limit (start/stop):',tweet[0].created_at)
        # return the id of the first tweet in the list
    return tweet[0].id

# %%
def write_tweets(tweets, filename):
    ''' Function that appends tweets to a file. '''

    with open(filename, 'a') as f:
        for tweet in tweets:
            json.dump(tweet._json, f)
            f.write('\n')

# %%
time_limit = 8                           # runtime limit in hours
max_tweets = 100                           # number of tweets per search (will be
                                               # iterated over) - maximum is 100
min_days_old, max_days_old = 8, 9          # search limits e.g., from 7 to 8
                                               # gives current weekday from last week,
                                               # min_days_old=0 will search from right now
Delhi = '28.626963,77.215396,50km'       # this geocode includes Delhi area
                                              
    

    # loop over search items,
    # creating a new file for each
    #for search_phrase in search_phrases:

     #   print('Search phrase =', search_phrase)

      #  ''' other variables '''
      #  name = search_phrase.split()[0]
      #  json_file_root = name + '/'  + name
       # os.makedirs(os.path.dirname(json_file_root), exist_ok=True)
read_IDs = False
        
        # open a file in which to store the tweets
if max_days_old - min_days_old == 1:
    d = dt.datetime.now() - dt.timedelta(days=min_days_old)
    day = '{0}-{1:0>2}-{2:0>2}'.format(d.year, d.month, d.day)
else:
    d1 = dt.datetime.now() - dt.timedelta(days=max_days_old-1)
    d2 = dt.datetime.now() - dt.timedelta(days=min_days_old)
    day = '{0}-{1:0>2}-{2:0>2}_to_{3}-{4:0>2}-{5:0>2}'.format(d1.year, d1.month, d1.day, d2.year, d2.month, d2.day)
json_file = 'Delhi' + '_' + day + '.json'
if os.path.isfile(json_file):
    print('Appending tweets to file named: ',json_file)
    read_IDs = True
        
        # authorize and load the twitter API
api = load_api()
        
        # set the 'starting point' ID for tweet collection
if read_IDs:
    # open the json file and get the latest tweet ID
    with open(json_file, 'r') as f:
        lines = f.readlines()
        max_id = json.loads(lines[-1])['id']
        print('Searching from the bottom ID in file')
else:
    # get the ID of a tweet that is min_days_old
    if min_days_old == 0:
        max_id = -1
    else:
        max_id = get_tweet_id(api, days_ago=(min_days_old-1))
    # set the smallest ID to search for
since_id = get_tweet_id(api, days_ago=(max_days_old-1))
print('max id (starting point) =', max_id)
print('since id (ending point) =', since_id)
        


''' tweet gathering loop  '''
start = dt.datetime.now()
end = start + dt.timedelta(hours=time_limit)
count, exitcount = 0, 0
while dt.datetime.now() < end:
    count += 1
    print('count =',count)
    # collect tweets and update max_id
    tweets, max_id = tweet_search(api, max_tweets,max_id=max_id, since_id=since_id,
                                          geocode=Delhi)
            # write tweets to file in JSON format
    if tweets:
        write_tweets(tweets, json_file)
        exitcount = 0
    else:
        exitcount += 1
        if exitcount == 3:
            print('Maximum number of empty tweet strings reached - breaking')
            break
# Out:
# search limit (start/stop): 2019-03-20 23:59:59
# search limit (start/stop): 2019-03-19 23:59:59
# max id (starting point) = 1108518582466605056
# since id (ending point) = 1108156194600955904
# count = 1
# found 91 tweets
# found 6 tweets
# found 2 tweets
# found 1 tweets
# count = 2
# found 93 tweets
# found 5 tweets
# found 2 tweets
# count = 3
# found 96 tweets
# found 4 tweets
# count = 4
# found 89 tweets
# found 6 tweets
# found 5 tweets
# count = 5
# found 82 tweets
# found 17 tweets
# found 0 tweets
# no tweets found
# count = 6
# found 80 tweets
# found 18 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 7
# found 93 tweets
# found 5 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 8
# found 93 tweets
# found 6 tweets
# found 1 tweets
# count = 9
# found 79 tweets
# found 17 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 10
# found 87 tweets
# found 13 tweets
# count = 11
# found 84 tweets
# found 10 tweets
# found 4 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 12
# found 89 tweets
# found 6 tweets
# found 4 tweets
# found 1 tweets
# count = 13
# found 89 tweets
# found 11 tweets
# count = 14
# found 91 tweets
# found 7 tweets
# found 2 tweets
# count = 15
# found 86 tweets
# found 12 tweets
# found 2 tweets
# count = 16
# found 89 tweets
# found 7 tweets
# found 2 tweets
# found 2 tweets
# count = 17
# found 88 tweets
# found 11 tweets
# found 1 tweets
# count = 18
# found 78 tweets
# found 18 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 19
# found 93 tweets
# found 6 tweets
# found 0 tweets
# no tweets found
# count = 20
# found 89 tweets
# found 11 tweets
# count = 21
# found 90 tweets
# found 6 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 22
# found 74 tweets
# found 23 tweets
# found 3 tweets
# count = 23
# found 76 tweets
# found 23 tweets
# found 1 tweets
# count = 24
# found 89 tweets
# found 10 tweets
# found 1 tweets
# count = 25
# found 83 tweets
# found 11 tweets
# found 5 tweets
# found 0 tweets
# no tweets found
# count = 26
# found 96 tweets
# found 3 tweets
# found 1 tweets
# count = 27
# found 92 tweets
# found 8 tweets
# count = 28
# found 87 tweets
# found 8 tweets
# found 4 tweets
# found 1 tweets
# count = 29
# found 93 tweets
# found 5 tweets
# found 0 tweets
# no tweets found
# count = 30
# found 86 tweets
# found 11 tweets
# found 2 tweets
# found 1 tweets
# count = 31
# found 84 tweets
# found 13 tweets
# found 3 tweets
# count = 32
# found 79 tweets
# found 21 tweets
# count = 33
# found 96 tweets
# found 1 tweets
# found 1 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 34
# found 91 tweets
# found 5 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 35
# found 83 tweets
# found 17 tweets
# count = 36
# found 92 tweets
# found 6 tweets
# found 2 tweets
# count = 37
# found 86 tweets
# found 14 tweets
# count = 38
# found 84 tweets
# found 14 tweets
# found 2 tweets
# count = 39
# found 91 tweets
# found 8 tweets
# found 1 tweets
# count = 40
# found 92 tweets
# found 5 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 41
# found 79 tweets
# found 17 tweets
# found 2 tweets
# found 2 tweets
# count = 42
# found 94 tweets
# found 5 tweets
# found 1 tweets
# count = 43
# found 98 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 44
# found 93 tweets
# found 6 tweets
# found 1 tweets
# count = 45
# found 99 tweets
# found 0 tweets
# no tweets found
# count = 46
# found 96 tweets
# found 3 tweets
# found 1 tweets
# count = 47
# found 84 tweets
# found 16 tweets
# count = 48
# found 87 tweets
# found 10 tweets
# found 2 tweets
# found 1 tweets
# count = 49
# found 88 tweets
# found 8 tweets
# found 3 tweets
# found 1 tweets
# count = 50
# found 81 tweets
# found 16 tweets
# found 3 tweets
# count = 51
# found 83 tweets
# found 15 tweets
# found 2 tweets
# count = 52
# found 81 tweets
# found 17 tweets
# found 2 tweets
# count = 53
# found 94 tweets
# found 6 tweets
# count = 54
# found 99 tweets
# found 1 tweets
# count = 55
# found 88 tweets
# found 9 tweets
# found 2 tweets
# found 1 tweets
# count = 56
# found 86 tweets
# found 13 tweets
# found 0 tweets
# no tweets found
# count = 57
# found 83 tweets
# exception raised, waiting 15 minutes
# (until: 2019-03-28 10:09:45.861640 )
# count = 58
# found 86 tweets
# found 11 tweets
# found 0 tweets
# no tweets found
# count = 59
# found 84 tweets
# found 16 tweets
# count = 60
# found 84 tweets
# found 12 tweets
# found 1 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 61
# found 91 tweets
# found 6 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 62
# found 92 tweets
# found 6 tweets
# found 2 tweets
# count = 63
# found 87 tweets
# found 11 tweets
# found 2 tweets
# count = 64
# found 93 tweets
# found 3 tweets
# found 3 tweets
# found 1 tweets
# count = 65
# found 100 tweets
# count = 66
# found 97 tweets
# found 3 tweets
# count = 67
# found 90 tweets
# found 8 tweets
# found 2 tweets
# count = 68
# found 97 tweets
# found 3 tweets
# count = 69
# found 94 tweets
# found 6 tweets
# count = 70
# found 88 tweets
# found 7 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 71
# found 87 tweets
# found 13 tweets
# count = 72
# found 96 tweets
# found 4 tweets
# count = 73
# found 88 tweets
# found 12 tweets
# count = 74
# found 82 tweets
# found 14 tweets
# found 2 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 75
# found 88 tweets
# found 10 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 76
# found 93 tweets
# found 5 tweets
# found 1 tweets
# found 1 tweets
# count = 77
# found 93 tweets
# found 7 tweets
# count = 78
# found 96 tweets
# found 1 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 79
# found 84 tweets
# found 14 tweets
# found 0 tweets
# no tweets found
# count = 80
# found 73 tweets
# found 25 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 81
# found 93 tweets
# found 7 tweets
# count = 82
# found 78 tweets
# found 16 tweets
# found 6 tweets
# count = 83
# found 87 tweets
# found 9 tweets
# found 3 tweets
# found 1 tweets
# count = 84
# found 90 tweets
# found 9 tweets
# found 1 tweets
# count = 85
# found 97 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 86
# found 88 tweets
# found 6 tweets
# found 4 tweets
# found 1 tweets
# found 1 tweets
# count = 87
# found 80 tweets
# found 20 tweets
# count = 88
# found 77 tweets
# found 11 tweets
# found 8 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 89
# found 78 tweets
# found 17 tweets
# found 5 tweets
# count = 90
# found 94 tweets
# found 4 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 91
# found 95 tweets
# found 4 tweets
# found 1 tweets
# count = 92
# found 90 tweets
# found 8 tweets
# found 0 tweets
# no tweets found
# count = 93
# found 97 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 94
# found 93 tweets
# found 7 tweets
# count = 95
# found 92 tweets
# found 7 tweets
# found 0 tweets
# no tweets found
# count = 96
# found 97 tweets
# found 2 tweets
# found 1 tweets
# count = 97
# found 89 tweets
# found 11 tweets
# count = 98
# found 83 tweets
# found 12 tweets
# found 5 tweets
# count = 99
# found 93 tweets
# found 7 tweets
# count = 100
# found 87 tweets
# found 9 tweets
# found 2 tweets
# found 1 tweets
# found 1 tweets
# count = 101
# found 88 tweets
# found 9 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 102
# found 87 tweets
# found 11 tweets
# found 0 tweets
# no tweets found
# count = 103
# found 80 tweets
# found 14 tweets
# found 5 tweets
# found 1 tweets
# count = 104
# found 79 tweets
# found 14 tweets
# found 4 tweets
# found 3 tweets
# count = 105
# found 80 tweets
# found 18 tweets
# found 2 tweets
# count = 106
# found 88 tweets
# found 9 tweets
# found 1 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 107
# found 92 tweets
# found 7 tweets
# found 0 tweets
# no tweets found
# count = 108
# found 84 tweets
# found 16 tweets
# count = 109
# found 86 tweets
# found 13 tweets
# found 0 tweets
# no tweets found
# count = 110
# found 89 tweets
# found 8 tweets
# found 0 tweets
# no tweets found
# count = 111
# found 79 tweets
# found 16 tweets
# found 3 tweets
# found 2 tweets
# count = 112
# found 88 tweets
# found 8 tweets
# found 2 tweets
# found 1 tweets
# found 1 tweets
# count = 113
# found 87 tweets
# found 13 tweets
# count = 114
# found 78 tweets
# found 16 tweets
# exception raised, waiting 15 minutes
# (until: 2019-03-28 10:26:48.011041 )
# count = 115
# found 85 tweets
# found 11 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 116
# found 85 tweets
# found 12 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 117
# found 86 tweets
# found 12 tweets
# found 2 tweets
# count = 118
# found 87 tweets
# found 11 tweets
# found 1 tweets
# found 1 tweets
# count = 119
# found 79 tweets
# found 19 tweets
# found 0 tweets
# no tweets found
# count = 120
# found 83 tweets
# found 17 tweets
# count = 121
# found 86 tweets
# found 11 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 122
# found 78 tweets
# found 20 tweets
# found 2 tweets
# count = 123
# found 80 tweets
# found 11 tweets
# found 6 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 124
# found 83 tweets
# found 15 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 125
# found 83 tweets
# found 12 tweets
# found 2 tweets
# found 3 tweets
# count = 126
# found 84 tweets
# found 11 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 127
# found 77 tweets
# found 18 tweets
# found 2 tweets
# found 2 tweets
# found 1 tweets
# count = 128
# found 81 tweets
# found 14 tweets
# found 5 tweets
# count = 129
# found 83 tweets
# found 14 tweets
# found 1 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 130
# found 86 tweets
# found 6 tweets
# found 5 tweets
# found 0 tweets
# no tweets found
# count = 131
# found 86 tweets
# found 14 tweets
# count = 132
# found 77 tweets
# found 22 tweets
# found 0 tweets
# no tweets found
# count = 133
# found 87 tweets
# found 13 tweets
# count = 134
# found 88 tweets
# found 9 tweets
# found 1 tweets
# found 2 tweets
# count = 135
# found 85 tweets
# found 15 tweets
# count = 136
# found 92 tweets
# found 5 tweets
# found 2 tweets
# found 1 tweets
# count = 137
# found 85 tweets
# found 13 tweets
# found 0 tweets
# no tweets found
# count = 138
# found 82 tweets
# found 13 tweets
# found 5 tweets
# count = 139
# found 84 tweets
# found 14 tweets
# found 2 tweets
# count = 140
# found 88 tweets
# found 11 tweets
# found 0 tweets
# no tweets found
# count = 141
# found 83 tweets
# found 13 tweets
# found 2 tweets
# found 1 tweets
# found 1 tweets
# count = 142
# found 94 tweets
# found 5 tweets
# found 0 tweets
# no tweets found
# count = 143
# found 96 tweets
# found 4 tweets
# count = 144
# found 89 tweets
# found 11 tweets
# count = 145
# found 88 tweets
# found 10 tweets
# found 1 tweets
# found 1 tweets
# count = 146
# found 96 tweets
# found 3 tweets
# found 1 tweets
# count = 147
# found 88 tweets
# found 11 tweets
# found 1 tweets
# count = 148
# found 84 tweets
# found 16 tweets
# count = 149
# found 87 tweets
# found 11 tweets
# found 0 tweets
# no tweets found
# count = 150
# found 97 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 151
# found 78 tweets
# found 22 tweets
# count = 152
# found 84 tweets
# found 14 tweets
# found 1 tweets
# found 1 tweets
# count = 153
# found 93 tweets
# found 6 tweets
# found 1 tweets
# count = 154
# found 90 tweets
# found 10 tweets
# count = 155
# found 82 tweets
# found 14 tweets
# found 3 tweets
# found 1 tweets
# count = 156
# found 95 tweets
# found 5 tweets
# count = 157
# found 85 tweets
# found 8 tweets
# found 4 tweets
# found 2 tweets
# found 1 tweets
# count = 158
# found 86 tweets
# found 10 tweets
# found 3 tweets
# found 1 tweets
# count = 159
# found 86 tweets
# found 11 tweets
# found 2 tweets
# found 1 tweets
# count = 160
# found 75 tweets
# found 23 tweets
# found 1 tweets
# found 1 tweets
# count = 161
# found 86 tweets
# found 11 tweets
# found 3 tweets
# count = 162
# found 87 tweets
# found 11 tweets
# found 2 tweets
# count = 163
# found 90 tweets
# found 8 tweets
# found 2 tweets
# count = 164
# found 85 tweets
# found 12 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 165
# found 84 tweets
# found 12 tweets
# found 1 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 166
# found 87 tweets
# found 11 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 167
# found 90 tweets
# found 8 tweets
# found 2 tweets
# count = 168
# found 90 tweets
# exception raised, waiting 15 minutes
# (until: 2019-03-28 10:44:05.743200 )
# count = 169
# found 92 tweets
# found 6 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 170
# found 89 tweets
# found 11 tweets
# count = 171
# found 96 tweets
# found 3 tweets
# found 1 tweets
# count = 172
# found 92 tweets
# found 3 tweets
# found 5 tweets
# count = 173
# found 94 tweets
# found 6 tweets
# count = 174
# found 96 tweets
# found 3 tweets
# found 1 tweets
# count = 175
# found 100 tweets
# count = 176
# found 100 tweets
# count = 177
# found 99 tweets
# found 1 tweets
# count = 178
# found 83 tweets
# found 12 tweets
# found 4 tweets
# found 1 tweets
# count = 179
# found 88 tweets
# found 10 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 180
# found 92 tweets
# found 8 tweets
# count = 181
# found 88 tweets
# found 11 tweets
# found 0 tweets
# no tweets found
# count = 182
# found 89 tweets
# found 7 tweets
# found 1 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 183
# found 94 tweets
# found 6 tweets
# count = 184
# found 85 tweets
# found 8 tweets
# found 6 tweets
# found 1 tweets
# count = 185
# found 85 tweets
# found 13 tweets
# found 2 tweets
# count = 186
# found 84 tweets
# found 15 tweets
# found 0 tweets
# no tweets found
# count = 187
# found 89 tweets
# found 9 tweets
# found 0 tweets
# no tweets found
# count = 188
# found 87 tweets
# found 13 tweets
# count = 189
# found 87 tweets
# found 7 tweets
# found 2 tweets
# found 3 tweets
# found 1 tweets
# count = 190
# found 90 tweets
# found 9 tweets
# found 0 tweets
# no tweets found
# count = 191
# found 85 tweets
# found 15 tweets
# count = 192
# found 97 tweets
# found 2 tweets
# found 1 tweets
# count = 193
# found 89 tweets
# found 11 tweets
# count = 194
# found 84 tweets
# found 13 tweets
# found 3 tweets
# count = 195
# found 78 tweets
# found 16 tweets
# found 6 tweets
# count = 196
# found 85 tweets
# found 11 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 197
# found 81 tweets
# found 13 tweets
# found 3 tweets
# found 3 tweets
# count = 198
# found 80 tweets
# found 17 tweets
# found 3 tweets
# count = 199
# found 73 tweets
# found 21 tweets
# found 3 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 200
# found 79 tweets
# found 18 tweets
# found 3 tweets
# count = 201
# found 71 tweets
# found 28 tweets
# found 1 tweets
# count = 202
# found 87 tweets
# found 13 tweets
# count = 203
# found 93 tweets
# found 3 tweets
# found 2 tweets
# found 1 tweets
# found 1 tweets
# count = 204
# found 86 tweets
# found 9 tweets
# found 5 tweets
# count = 205
# found 87 tweets
# found 11 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 206
# found 87 tweets
# found 10 tweets
# found 1 tweets
# found 2 tweets
# count = 207
# found 82 tweets
# found 14 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 208
# found 85 tweets
# found 10 tweets
# found 5 tweets
# count = 209
# found 85 tweets
# found 13 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 210
# found 84 tweets
# found 14 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 211
# found 76 tweets
# found 18 tweets
# found 6 tweets
# count = 212
# found 85 tweets
# found 10 tweets
# found 0 tweets
# no tweets found
# count = 213
# found 74 tweets
# found 22 tweets
# found 3 tweets
# found 1 tweets
# count = 214
# found 88 tweets
# found 12 tweets
# count = 215
# found 86 tweets
# found 11 tweets
# found 1 tweets
# found 2 tweets
# count = 216
# found 86 tweets
# found 11 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 217
# found 81 tweets
# found 18 tweets
# found 0 tweets
# no tweets found
# count = 218
# found 98 tweets
# found 2 tweets
# count = 219
# found 86 tweets
# found 14 tweets
# count = 220
# found 95 tweets
# found 4 tweets
# found 1 tweets
# count = 221
# found 88 tweets
# found 10 tweets
# found 0 tweets
# no tweets found
# count = 222
# found 85 tweets
# found 15 tweets
# count = 223
# found 89 tweets
# found 11 tweets
# count = 224
# found 93 tweets
# found 5 tweets
# found 2 tweets
# count = 225
# found 85 tweets
# found 13 tweets
# found 2 tweets
# count = 226
# found 91 tweets
# found 8 tweets
# found 1 tweets
# count = 227
# found 91 tweets
# found 5 tweets
# exception raised, waiting 15 minutes
# (until: 2019-03-28 11:01:04.780168 )
# count = 228
# found 85 tweets
# found 15 tweets
# count = 229
# found 92 tweets
# found 6 tweets
# found 1 tweets
# found 1 tweets
# count = 230
# found 90 tweets
# found 8 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 231
# found 86 tweets
# found 13 tweets
# found 0 tweets
# no tweets found
# count = 232
# found 82 tweets
# found 15 tweets
# found 3 tweets
# count = 233
# found 91 tweets
# found 8 tweets
# found 1 tweets
# count = 234
# found 94 tweets
# found 2 tweets
# found 1 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 235
# found 92 tweets
# found 8 tweets
# count = 236
# found 86 tweets
# found 13 tweets
# found 0 tweets
# no tweets found
# count = 237
# found 87 tweets
# found 13 tweets
# count = 238
# found 87 tweets
# found 12 tweets
# found 1 tweets
# count = 239
# found 97 tweets
# found 2 tweets
# found 1 tweets
# count = 240
# found 92 tweets
# found 5 tweets
# found 3 tweets
# count = 241
# found 92 tweets
# found 5 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 242
# found 90 tweets
# found 10 tweets
# count = 243
# found 86 tweets
# found 11 tweets
# found 2 tweets
# found 1 tweets
# count = 244
# found 88 tweets
# found 8 tweets
# found 3 tweets
# found 1 tweets
# count = 245
# found 86 tweets
# found 12 tweets
# found 1 tweets
# found 1 tweets
# count = 246
# found 89 tweets
# found 6 tweets
# found 4 tweets
# found 0 tweets
# no tweets found
# count = 247
# found 88 tweets
# found 11 tweets
# found 0 tweets
# no tweets found
# count = 248
# found 95 tweets
# found 5 tweets
# count = 249
# found 93 tweets
# found 7 tweets
# count = 250
# found 86 tweets
# found 12 tweets
# found 2 tweets
# count = 251
# found 100 tweets
# count = 252
# found 100 tweets
# count = 253
# found 89 tweets
# found 11 tweets
# count = 254
# found 89 tweets
# found 5 tweets
# found 5 tweets
# found 0 tweets
# no tweets found
# count = 255
# found 91 tweets
# found 8 tweets
# found 1 tweets
# count = 256
# found 83 tweets
# found 16 tweets
# found 0 tweets
# no tweets found
# count = 257
# found 93 tweets
# found 6 tweets
# found 1 tweets
# count = 258
# found 92 tweets
# found 7 tweets
# found 0 tweets
# no tweets found
# count = 259
# found 92 tweets
# found 7 tweets
# found 1 tweets
# count = 260
# found 93 tweets
# found 4 tweets
# found 3 tweets
# count = 261
# found 91 tweets
# found 9 tweets
# count = 262
# found 99 tweets
# found 1 tweets
# count = 263
# found 89 tweets
# found 11 tweets
# count = 264
# found 99 tweets
# found 1 tweets
# count = 265
# found 88 tweets
# found 9 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 266
# found 93 tweets
# found 4 tweets
# found 2 tweets
# found 1 tweets
# count = 267
# found 95 tweets
# found 4 tweets
# found 1 tweets
# count = 268
# found 88 tweets
# found 11 tweets
# found 1 tweets
# count = 269
# found 97 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 270
# found 80 tweets
# found 16 tweets
# found 1 tweets
# found 1 tweets
# found 1 tweets
# found 1 tweets
# count = 271
# found 80 tweets
# found 19 tweets
# found 0 tweets
# no tweets found
# count = 272
# found 81 tweets
# found 16 tweets
# found 3 tweets
# count = 273
# found 75 tweets
# found 24 tweets
# found 1 tweets
# count = 274
# found 93 tweets
# found 4 tweets
# found 0 tweets
# no tweets found
# count = 275
# found 88 tweets
# found 10 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 276
# found 80 tweets
# found 18 tweets
# found 2 tweets
# count = 277
# found 80 tweets
# found 16 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 278
# found 88 tweets
# found 12 tweets
# count = 279
# found 91 tweets
# found 6 tweets
# found 1 tweets
# found 2 tweets
# count = 280
# found 96 tweets
# found 3 tweets
# found 1 tweets
# count = 281
# found 90 tweets
# found 10 tweets
# count = 282
# found 92 tweets
# found 7 tweets
# found 1 tweets
# count = 283
# found 91 tweets
# found 8 tweets
# found 0 tweets
# no tweets found
# count = 284
# found 97 tweets
# found 1 tweets
# found 2 tweets
# count = 285
# found 89 tweets
# found 9 tweets
# found 2 tweets
# count = 286
# found 91 tweets
# found 9 tweets
# count = 287
# found 100 tweets
# count = 288
# found 91 tweets
# found 6 tweets
# exception raised, waiting 15 minutes
# (until: 2019-03-28 11:19:14.412822 )
# count = 289
# found 85 tweets
# found 10 tweets
# found 4 tweets
# found 1 tweets
# count = 290
# found 87 tweets
# found 10 tweets
# found 2 tweets
# found 1 tweets
# count = 291
# found 86 tweets
# found 14 tweets
# count = 292
# found 99 tweets
# found 1 tweets
# count = 293
# found 92 tweets
# found 7 tweets
# found 1 tweets
# count = 294
# found 94 tweets
# found 5 tweets
# found 1 tweets
# count = 295
# found 91 tweets
# found 7 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 296
# found 97 tweets
# found 3 tweets
# count = 297
# found 85 tweets
# found 10 tweets
# found 5 tweets
# count = 298
# found 98 tweets
# found 2 tweets
# count = 299
# found 96 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 300
# found 91 tweets
# found 7 tweets
# found 2 tweets
# count = 301
# found 86 tweets
# found 14 tweets
# count = 302
# found 88 tweets
# found 11 tweets
# found 0 tweets
# no tweets found
# count = 303
# found 89 tweets
# found 6 tweets
# found 3 tweets
# found 2 tweets
# count = 304
# found 91 tweets
# found 7 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 305
# found 91 tweets
# found 8 tweets
# found 0 tweets
# no tweets found
# count = 306
# found 97 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 307
# found 91 tweets
# found 9 tweets
# count = 308
# found 88 tweets
# found 7 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 309
# found 93 tweets
# found 7 tweets
# count = 310
# found 92 tweets
# found 7 tweets
# found 0 tweets
# no tweets found
# count = 311
# found 92 tweets
# found 6 tweets
# found 2 tweets
# count = 312
# found 100 tweets
# count = 313
# found 92 tweets
# found 7 tweets
# found 0 tweets
# no tweets found
# count = 314
# found 92 tweets
# found 8 tweets
# count = 315
# found 100 tweets
# count = 316
# found 86 tweets
# found 12 tweets
# found 1 tweets
# found 1 tweets
# count = 317
# found 87 tweets
# found 9 tweets
# found 4 tweets
# count = 318
# found 82 tweets
# found 15 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 319
# found 98 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 320
# found 93 tweets
# found 6 tweets
# found 1 tweets
# count = 321
# found 94 tweets
# found 4 tweets
# found 1 tweets
# found 1 tweets
# count = 322
# found 92 tweets
# found 8 tweets
# count = 323
# found 96 tweets
# found 3 tweets
# found 1 tweets
# count = 324
# found 88 tweets
# found 11 tweets
# found 1 tweets
# count = 325
# found 90 tweets
# found 9 tweets
# found 0 tweets
# no tweets found
# count = 326
# found 78 tweets
# found 21 tweets
# found 0 tweets
# no tweets found
# count = 327
# found 79 tweets
# found 19 tweets
# found 1 tweets
# found 1 tweets
# count = 328
# found 89 tweets
# found 8 tweets
# found 3 tweets
# count = 329
# found 100 tweets
# count = 330
# found 90 tweets
# found 10 tweets
# count = 331
# found 95 tweets
# found 5 tweets
# count = 332
# found 87 tweets
# found 11 tweets
# found 1 tweets
# found 1 tweets
# count = 333
# found 85 tweets
# found 15 tweets
# count = 334
# found 93 tweets
# found 4 tweets
# found 2 tweets
# found 1 tweets
# count = 335
# found 97 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 336
# found 88 tweets
# found 10 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 337
# found 92 tweets
# found 8 tweets
# count = 338
# found 98 tweets
# found 1 tweets
# found 1 tweets
# count = 339
# found 95 tweets
# found 4 tweets
# found 0 tweets
# no tweets found
# count = 340
# found 88 tweets
# found 11 tweets
# found 0 tweets
# no tweets found
# count = 341
# found 97 tweets
# found 3 tweets
# count = 342
# found 95 tweets
# found 5 tweets
# count = 343
# found 99 tweets
# found 1 tweets
# count = 344
# found 91 tweets
# found 8 tweets
# found 0 tweets
# no tweets found
# count = 345
# found 100 tweets
# count = 346
# found 88 tweets
# found 8 tweets
# found 3 tweets
# found 1 tweets
# count = 347
# found 89 tweets
# found 10 tweets
# found 1 tweets
# count = 348
# found 82 tweets
# found 16 tweets
# found 1 tweets
# found 1 tweets
# count = 349
# found 92 tweets
# found 8 tweets
# count = 350
# found 90 tweets
# found 8 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 351
# found 90 tweets
# found 8 tweets
# found 2 tweets
# count = 352
# exception raised, waiting 15 minutes
# (until: 2019-03-28 11:36:21.610653 )
# count = 353
# found 87 tweets
# found 12 tweets
# found 0 tweets
# no tweets found
# count = 354
# found 92 tweets
# found 8 tweets
# count = 355
# found 95 tweets
# found 3 tweets
# found 2 tweets
# count = 356
# found 86 tweets
# found 10 tweets
# found 2 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 357
# found 88 tweets
# found 11 tweets
# found 1 tweets
# count = 358
# found 84 tweets
# found 13 tweets
# found 2 tweets
# found 1 tweets
# count = 359
# found 84 tweets
# found 15 tweets
# found 1 tweets
# count = 360
# found 89 tweets
# found 7 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 361
# found 87 tweets
# found 11 tweets
# found 0 tweets
# no tweets found
# count = 362
# found 84 tweets
# found 15 tweets
# found 0 tweets
# no tweets found
# count = 363
# found 92 tweets
# found 4 tweets
# found 2 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 364
# found 92 tweets
# found 5 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 365
# found 85 tweets
# found 13 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 366
# found 82 tweets
# found 14 tweets
# found 4 tweets
# count = 367
# found 90 tweets
# found 10 tweets
# count = 368
# found 87 tweets
# found 11 tweets
# found 1 tweets
# found 1 tweets
# count = 369
# found 85 tweets
# found 9 tweets
# found 4 tweets
# found 0 tweets
# no tweets found
# count = 370
# found 88 tweets
# found 10 tweets
# found 1 tweets
# found 1 tweets
# count = 371
# found 86 tweets
# found 9 tweets
# found 5 tweets
# count = 372
# found 87 tweets
# found 13 tweets
# count = 373
# found 85 tweets
# found 12 tweets
# found 3 tweets
# count = 374
# found 93 tweets
# found 4 tweets
# found 2 tweets
# found 1 tweets
# count = 375
# found 96 tweets
# found 4 tweets
# count = 376
# found 97 tweets
# found 3 tweets
# count = 377
# found 85 tweets
# found 12 tweets
# found 3 tweets
# count = 378
# found 94 tweets
# found 4 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 379
# found 93 tweets
# found 3 tweets
# found 1 tweets
# found 2 tweets
# found 1 tweets
# count = 380
# found 89 tweets
# found 11 tweets
# count = 381
# found 92 tweets
# found 4 tweets
# found 1 tweets
# found 1 tweets
# found 1 tweets
# found 1 tweets
# count = 382
# found 83 tweets
# found 15 tweets
# found 2 tweets
# count = 383
# found 92 tweets
# found 6 tweets
# found 2 tweets
# count = 384
# found 94 tweets
# found 6 tweets
# count = 385
# found 80 tweets
# found 17 tweets
# found 3 tweets
# count = 386
# found 84 tweets
# found 12 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 387
# found 91 tweets
# found 9 tweets
# count = 388
# found 87 tweets
# found 9 tweets
# found 2 tweets
# found 1 tweets
# found 1 tweets
# count = 389
# found 88 tweets
# found 11 tweets
# found 1 tweets
# count = 390
# found 92 tweets
# found 7 tweets
# found 1 tweets
# count = 391
# found 94 tweets
# found 6 tweets
# count = 392
# found 99 tweets
# found 1 tweets
# count = 393
# found 87 tweets
# found 10 tweets
# found 3 tweets
# count = 394
# found 88 tweets
# found 9 tweets
# found 3 tweets
# count = 395
# found 89 tweets
# found 10 tweets
# found 1 tweets
# count = 396
# found 82 tweets
# found 17 tweets
# found 0 tweets
# no tweets found
# count = 397
# found 86 tweets
# found 13 tweets
# found 1 tweets
# count = 398
# found 90 tweets
# found 10 tweets
# count = 399
# found 94 tweets
# found 5 tweets
# found 0 tweets
# no tweets found
# count = 400
# found 91 tweets
# found 8 tweets
# found 0 tweets
# no tweets found
# count = 401
# found 88 tweets
# found 11 tweets
# found 1 tweets
# count = 402
# found 85 tweets
# found 13 tweets
# found 2 tweets
# count = 403
# found 91 tweets
# found 9 tweets
# count = 404
# found 93 tweets
# found 4 tweets
# found 1 tweets
# found 2 tweets
# count = 405
# found 88 tweets
# found 11 tweets
# found 1 tweets
# count = 406
# found 90 tweets
# found 10 tweets
# count = 407
# found 90 tweets
# found 9 tweets
# found 0 tweets
# no tweets found
# count = 408
# found 89 tweets
# found 10 tweets
# found 0 tweets
# no tweets found
# count = 409
# found 95 tweets
# found 3 tweets
# found 2 tweets
# count = 410
# exception raised, waiting 15 minutes
# (until: 2019-03-28 11:53:24.737802 )
# count = 411
# found 94 tweets
# found 5 tweets
# found 0 tweets
# no tweets found
# count = 412
# found 86 tweets
# found 11 tweets
# found 2 tweets
# found 1 tweets
# count = 413
# found 83 tweets
# found 11 tweets
# found 3 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 414
# found 78 tweets
# found 16 tweets
# found 5 tweets
# found 0 tweets
# no tweets found
# count = 415
# found 83 tweets
# found 13 tweets
# found 3 tweets
# found 1 tweets
# count = 416
# found 98 tweets
# found 2 tweets
# count = 417
# found 86 tweets
# found 12 tweets
# found 2 tweets
# count = 418
# found 95 tweets
# found 5 tweets
# count = 419
# found 88 tweets
# found 10 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 420
# found 95 tweets
# found 5 tweets
# count = 421
# found 94 tweets
# found 5 tweets
# found 1 tweets
# count = 422
# found 99 tweets
# found 0 tweets
# no tweets found
# count = 423
# found 86 tweets
# found 12 tweets
# found 1 tweets
# found 1 tweets
# count = 424
# found 100 tweets
# count = 425
# found 93 tweets
# found 7 tweets
# count = 426
# found 89 tweets
# found 6 tweets
# found 5 tweets
# count = 427
# found 96 tweets
# found 3 tweets
# found 1 tweets
# count = 428
# found 90 tweets
# found 10 tweets
# count = 429
# found 99 tweets
# found 1 tweets
# count = 430
# found 93 tweets
# found 7 tweets
# count = 431
# found 90 tweets
# found 10 tweets
# count = 432
# found 98 tweets
# found 0 tweets
# no tweets found
# count = 433
# found 93 tweets
# found 6 tweets
# found 0 tweets
# no tweets found
# count = 434
# found 87 tweets
# found 8 tweets
# found 4 tweets
# found 0 tweets
# no tweets found
# count = 435
# found 91 tweets
# found 6 tweets
# found 1 tweets
# found 2 tweets
# count = 436
# found 97 tweets
# found 3 tweets
# count = 437
# found 90 tweets
# found 9 tweets
# found 1 tweets
# count = 438
# found 90 tweets
# found 10 tweets
# count = 439
# found 90 tweets
# found 8 tweets
# found 2 tweets
# count = 440
# found 98 tweets
# found 1 tweets
# found 1 tweets
# count = 441
# found 88 tweets
# found 8 tweets
# found 3 tweets
# found 1 tweets
# count = 442
# found 90 tweets
# found 10 tweets
# count = 443
# found 95 tweets
# found 4 tweets
# found 0 tweets
# no tweets found
# count = 444
# found 90 tweets
# found 9 tweets
# found 1 tweets
# count = 445
# found 86 tweets
# found 11 tweets
# found 2 tweets
# found 1 tweets
# count = 446
# found 83 tweets
# found 15 tweets
# found 1 tweets
# found 1 tweets
# count = 447
# found 98 tweets
# found 1 tweets
# found 1 tweets
# count = 448
# found 96 tweets
# found 1 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 449
# found 90 tweets
# found 10 tweets
# count = 450
# found 90 tweets
# found 9 tweets
# found 0 tweets
# no tweets found
# count = 451
# found 87 tweets
# found 11 tweets
# found 2 tweets
# count = 452
# found 99 tweets
# found 0 tweets
# no tweets found
# count = 453
# found 91 tweets
# found 9 tweets
# count = 454
# found 92 tweets
# found 4 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 455
# found 89 tweets
# found 9 tweets
# found 0 tweets
# no tweets found
# count = 456
# found 84 tweets
# found 15 tweets
# found 1 tweets
# count = 457
# found 91 tweets
# found 8 tweets
# found 0 tweets
# no tweets found
# count = 458
# found 92 tweets
# found 7 tweets
# found 1 tweets
# count = 459
# found 88 tweets
# found 8 tweets
# found 4 tweets
# count = 460
# found 88 tweets
# found 12 tweets
# count = 461
# found 89 tweets
# found 7 tweets
# found 1 tweets
# found 1 tweets
# found 1 tweets
# found 1 tweets
# count = 462
# found 91 tweets
# found 8 tweets
# found 1 tweets
# count = 463
# found 83 tweets
# found 16 tweets
# found 1 tweets
# count = 464
# found 88 tweets
# found 11 tweets
# found 0 tweets
# no tweets found
# count = 465
# found 84 tweets
# found 12 tweets
# found 3 tweets
# found 1 tweets
# count = 466
# found 97 tweets
# found 1 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 467
# found 85 tweets
# found 14 tweets
# found 0 tweets
# no tweets found
# count = 468
# found 84 tweets
# found 15 tweets
# found 0 tweets
# no tweets found
# count = 469
# found 92 tweets
# found 4 tweets
# found 0 tweets
# no tweets found
# count = 470
# found 88 tweets
# found 8 tweets
# found 3 tweets
# exception raised, waiting 15 minutes
# (until: 2019-03-28 12:10:39.643067 )
# count = 471
# found 86 tweets
# found 10 tweets
# found 1 tweets
# found 2 tweets
# found 1 tweets
# count = 472
# found 91 tweets
# found 6 tweets
# found 1 tweets
# found 2 tweets
# count = 473
# found 99 tweets
# found 1 tweets
# count = 474
# found 91 tweets
# found 7 tweets
# found 2 tweets
# count = 475
# found 93 tweets
# found 3 tweets
# found 3 tweets
# found 1 tweets
# count = 476
# found 98 tweets
# found 2 tweets
# count = 477
# found 91 tweets
# found 7 tweets
# found 1 tweets
# found 1 tweets
# count = 478
# found 92 tweets
# found 6 tweets
# found 1 tweets
# found 1 tweets
# count = 479
# found 93 tweets
# found 6 tweets
# found 0 tweets
# no tweets found
# count = 480
# found 95 tweets
# found 4 tweets
# found 0 tweets
# no tweets found
# count = 481
# found 93 tweets
# found 7 tweets
# count = 482
# found 86 tweets
# found 14 tweets
# count = 483
# found 94 tweets
# found 4 tweets
# found 0 tweets
# no tweets found
# count = 484
# found 91 tweets
# found 9 tweets
# count = 485
# found 89 tweets
# found 8 tweets
# found 1 tweets
# found 2 tweets
# count = 486
# found 92 tweets
# found 8 tweets
# count = 487
# found 93 tweets
# found 3 tweets
# found 2 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 488
# found 86 tweets
# found 12 tweets
# found 2 tweets
# count = 489
# found 86 tweets
# found 12 tweets
# found 1 tweets
# found 1 tweets
# count = 490
# found 87 tweets
# found 12 tweets
# found 0 tweets
# no tweets found
# count = 491
# found 85 tweets
# found 11 tweets
# found 4 tweets
# count = 492
# found 84 tweets
# found 11 tweets
# found 2 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 493
# found 89 tweets
# found 7 tweets
# found 4 tweets
# count = 494
# found 82 tweets
# found 15 tweets
# found 3 tweets
# count = 495
# found 90 tweets
# found 9 tweets
# found 1 tweets
# count = 496
# found 87 tweets
# found 12 tweets
# found 1 tweets
# count = 497
# found 84 tweets
# found 12 tweets
# found 1 tweets
# found 1 tweets
# found 2 tweets
# count = 498
# found 91 tweets
# found 8 tweets
# found 0 tweets
# no tweets found
# count = 499
# found 82 tweets
# found 14 tweets
# found 2 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 500
# found 93 tweets
# found 4 tweets
# found 2 tweets
# found 1 tweets
# count = 501
# found 78 tweets
# found 22 tweets
# count = 502
# found 90 tweets
# found 9 tweets
# found 0 tweets
# no tweets found
# count = 503
# found 92 tweets
# found 7 tweets
# found 1 tweets
# count = 504
# found 97 tweets
# found 2 tweets
# found 1 tweets
# count = 505
# found 91 tweets
# found 9 tweets
# count = 506
# found 97 tweets
# found 2 tweets
# found 1 tweets
# count = 507
# found 83 tweets
# found 17 tweets
# count = 508
# found 90 tweets
# found 9 tweets
# found 1 tweets
# count = 509
# found 88 tweets
# found 10 tweets
# found 2 tweets
# count = 510
# found 89 tweets
# found 9 tweets
# found 1 tweets
# found 1 tweets
# count = 511
# found 92 tweets
# found 7 tweets
# found 1 tweets
# count = 512
# found 86 tweets
# found 7 tweets
# found 3 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 513
# found 91 tweets
# found 6 tweets
# found 2 tweets
# found 1 tweets
# count = 514
# found 93 tweets
# found 6 tweets
# found 0 tweets
# no tweets found
# count = 515
# found 78 tweets
# found 20 tweets
# found 2 tweets
# count = 516
# found 97 tweets
# found 3 tweets
# count = 517
# found 87 tweets
# found 13 tweets
# count = 518
# found 89 tweets
# found 10 tweets
# found 0 tweets
# no tweets found
# count = 519
# found 94 tweets
# found 5 tweets
# found 1 tweets
# count = 520
# found 87 tweets
# found 10 tweets
# found 0 tweets
# no tweets found
# count = 521
# found 90 tweets
# found 7 tweets
# found 3 tweets
# count = 522
# found 94 tweets
# found 4 tweets
# found 1 tweets
# found 1 tweets
# count = 523
# found 86 tweets
# found 11 tweets
# found 0 tweets
# no tweets found
# count = 524
# found 84 tweets
# found 13 tweets
# found 2 tweets
# found 1 tweets
# count = 525
# found 92 tweets
# found 6 tweets
# found 2 tweets
# count = 526
# found 86 tweets
# found 11 tweets
# found 1 tweets
# exception raised, waiting 15 minutes
# (until: 2019-03-28 12:27:48.197865 )
# count = 527
# found 86 tweets
# found 6 tweets
# found 6 tweets
# found 2 tweets
# count = 528
# found 89 tweets
# found 10 tweets
# found 0 tweets
# no tweets found
# count = 529
# found 82 tweets
# found 15 tweets
# found 0 tweets
# no tweets found
# count = 530
# found 87 tweets
# found 13 tweets
# count = 531
# found 81 tweets
# found 15 tweets
# found 4 tweets
# count = 532
# found 100 tweets
# count = 533
# found 94 tweets
# found 5 tweets
# found 0 tweets
# no tweets found
# count = 534
# found 88 tweets
# found 8 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 535
# found 89 tweets
# found 7 tweets
# found 2 tweets
# found 2 tweets
# count = 536
# found 80 tweets
# found 17 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 537
# found 94 tweets
# found 5 tweets
# found 0 tweets
# no tweets found
# count = 538
# found 81 tweets
# found 18 tweets
# found 1 tweets
# count = 539
# found 97 tweets
# found 3 tweets
# count = 540
# found 88 tweets
# found 10 tweets
# found 0 tweets
# no tweets found
# count = 541
# found 88 tweets
# found 9 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 542
# found 90 tweets
# found 5 tweets
# found 2 tweets
# found 1 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 543
# found 80 tweets
# found 19 tweets
# found 0 tweets
# no tweets found
# count = 544
# found 90 tweets
# found 10 tweets
# count = 545
# found 85 tweets
# found 12 tweets
# found 3 tweets
# count = 546
# found 90 tweets
# found 7 tweets
# found 2 tweets
# found 1 tweets
# count = 547
# found 91 tweets
# found 6 tweets
# found 1 tweets
# found 1 tweets
# found 1 tweets
# count = 548
# found 89 tweets
# found 11 tweets
# count = 549
# found 90 tweets
# found 10 tweets
# count = 550
# found 99 tweets
# found 1 tweets
# count = 551
# found 97 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 552
# found 90 tweets
# found 10 tweets
# count = 553
# found 94 tweets
# found 5 tweets
# found 0 tweets
# no tweets found
# count = 554
# found 97 tweets
# found 0 tweets
# no tweets found
# count = 555
# found 92 tweets
# found 8 tweets
# count = 556
# found 93 tweets
# found 6 tweets
# found 1 tweets
# count = 557
# found 94 tweets
# found 5 tweets
# found 1 tweets
# count = 558
# found 91 tweets
# found 8 tweets
# found 1 tweets
# count = 559
# found 90 tweets
# found 8 tweets
# found 0 tweets
# no tweets found
# count = 560
# found 89 tweets
# found 7 tweets
# found 3 tweets
# found 1 tweets
# count = 561
# found 85 tweets
# found 13 tweets
# found 1 tweets
# found 1 tweets
# count = 562
# found 96 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 563
# found 90 tweets
# found 10 tweets
# count = 564
# found 86 tweets
# found 12 tweets
# found 2 tweets
# count = 565
# found 87 tweets
# found 11 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 566
# found 87 tweets
# found 11 tweets
# found 2 tweets
# count = 567
# found 83 tweets
# found 14 tweets
# found 3 tweets
# count = 568
# found 87 tweets
# found 11 tweets
# found 1 tweets
# found 1 tweets
# count = 569
# found 77 tweets
# found 20 tweets
# found 3 tweets
# count = 570
# found 96 tweets
# found 2 tweets
# found 2 tweets
# count = 571
# found 90 tweets
# found 8 tweets
# found 2 tweets
# count = 572
# found 88 tweets
# found 10 tweets
# found 1 tweets
# found 1 tweets
# count = 573
# found 85 tweets
# found 13 tweets
# found 2 tweets
# count = 574
# found 82 tweets
# found 14 tweets
# found 1 tweets
# found 3 tweets
# count = 575
# found 92 tweets
# found 8 tweets
# count = 576
# found 87 tweets
# found 10 tweets
# found 3 tweets
# count = 577
# found 93 tweets
# found 6 tweets
# found 1 tweets
# count = 578
# found 85 tweets
# found 10 tweets
# found 4 tweets
# found 1 tweets
# count = 579
# found 92 tweets
# found 5 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 580
# found 79 tweets
# found 18 tweets
# found 3 tweets
# count = 581
# found 85 tweets
# found 15 tweets
# count = 582
# found 88 tweets
# found 10 tweets
# found 2 tweets
# count = 583
# found 87 tweets
# found 11 tweets
# found 2 tweets
# count = 584
# found 99 tweets
# found 0 tweets
# no tweets found
# count = 585
# found 93 tweets
# found 4 tweets
# exception raised, waiting 15 minutes
# (until: 2019-03-28 12:45:03.658825 )
# count = 586
# found 87 tweets
# found 11 tweets
# found 2 tweets
# count = 587
# found 96 tweets
# found 3 tweets
# found 1 tweets
# count = 588
# found 88 tweets
# found 9 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 589
# found 92 tweets
# found 7 tweets
# found 0 tweets
# no tweets found
# count = 590
# found 91 tweets
# found 7 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 591
# found 93 tweets
# found 6 tweets
# found 1 tweets
# count = 592
# found 88 tweets
# found 10 tweets
# found 1 tweets
# found 1 tweets
# count = 593
# found 96 tweets
# found 2 tweets
# found 2 tweets
# count = 594
# found 92 tweets
# found 7 tweets
# found 1 tweets
# count = 595
# found 84 tweets
# found 14 tweets
# found 0 tweets
# no tweets found
# count = 596
# found 93 tweets
# found 4 tweets
# found 3 tweets
# count = 597
# found 90 tweets
# found 8 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 598
# found 96 tweets
# found 3 tweets
# found 1 tweets
# count = 599
# found 93 tweets
# found 6 tweets
# found 1 tweets
# count = 600
# found 96 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 601
# found 77 tweets
# found 19 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 602
# found 85 tweets
# found 15 tweets
# count = 603
# found 94 tweets
# found 4 tweets
# found 2 tweets
# count = 604
# found 87 tweets
# found 10 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 605
# found 91 tweets
# found 8 tweets
# found 1 tweets
# count = 606
# found 98 tweets
# found 1 tweets
# found 1 tweets
# count = 607
# found 84 tweets
# found 16 tweets
# count = 608
# found 96 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 609
# found 82 tweets
# found 17 tweets
# found 0 tweets
# no tweets found
# count = 610
# found 85 tweets
# found 14 tweets
# found 0 tweets
# no tweets found
# count = 611
# found 83 tweets
# found 15 tweets
# found 2 tweets
# count = 612
# found 78 tweets
# found 20 tweets
# found 2 tweets
# count = 613
# found 84 tweets
# found 14 tweets
# found 2 tweets
# count = 614
# found 88 tweets
# found 9 tweets
# found 1 tweets
# found 1 tweets
# found 1 tweets
# count = 615
# found 87 tweets
# found 13 tweets
# count = 616
# found 82 tweets
# found 15 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 617
# found 90 tweets
# found 9 tweets
# found 1 tweets
# count = 618
# found 85 tweets
# found 14 tweets
# found 1 tweets
# count = 619
# found 100 tweets
# count = 620
# found 86 tweets
# found 12 tweets
# found 0 tweets
# no tweets found
# count = 621
# found 97 tweets
# found 1 tweets
# found 1 tweets
# found 1 tweets
# count = 622
# found 74 tweets
# found 21 tweets
# found 5 tweets
# count = 623
# found 91 tweets
# found 8 tweets
# found 0 tweets
# no tweets found
# count = 624
# found 84 tweets
# found 15 tweets
# found 1 tweets
# count = 625
# found 90 tweets
# found 9 tweets
# found 0 tweets
# no tweets found
# count = 626
# found 79 tweets
# found 15 tweets
# found 2 tweets
# found 4 tweets
# count = 627
# found 79 tweets
# found 20 tweets
# found 0 tweets
# no tweets found
# count = 628
# found 83 tweets
# found 13 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 629
# found 78 tweets
# found 21 tweets
# found 0 tweets
# no tweets found
# count = 630
# found 84 tweets
# found 16 tweets
# count = 631
# found 77 tweets
# found 22 tweets
# found 0 tweets
# no tweets found
# count = 632
# found 90 tweets
# found 10 tweets
# count = 633
# found 84 tweets
# found 14 tweets
# found 2 tweets
# count = 634
# found 84 tweets
# found 15 tweets
# found 0 tweets
# no tweets found
# count = 635
# found 89 tweets
# found 8 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 636
# found 89 tweets
# found 8 tweets
# found 2 tweets
# found 1 tweets
# count = 637
# found 84 tweets
# found 14 tweets
# found 2 tweets
# count = 638
# found 83 tweets
# found 12 tweets
# found 1 tweets
# found 3 tweets
# found 1 tweets
# count = 639
# found 72 tweets
# found 22 tweets
# found 3 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 640
# found 89 tweets
# found 9 tweets
# found 0 tweets
# no tweets found
# count = 641
# found 87 tweets
# found 12 tweets
# found 1 tweets
# count = 642
# found 94 tweets
# exception raised, waiting 15 minutes
# (until: 2019-03-28 13:02:11.420880 )
# count = 643
# exception raised, waiting 15 minutes
# (until: 2019-03-28 13:17:31.622926 )
# count = 644
# found 86 tweets
# found 9 tweets
# found 1 tweets
# found 3 tweets
# found 1 tweets
# count = 645
# found 90 tweets
# found 5 tweets
# found 4 tweets
# found 0 tweets
# no tweets found
# count = 646
# found 83 tweets
# found 15 tweets
# found 1 tweets
# found 1 tweets
# count = 647
# found 92 tweets
# found 8 tweets
# count = 648
# found 91 tweets
# found 7 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 649
# found 80 tweets
# found 17 tweets
# found 3 tweets
# count = 650
# found 86 tweets
# found 14 tweets
# count = 651
# found 86 tweets
# found 10 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 652
# found 87 tweets
# found 10 tweets
# found 2 tweets
# found 1 tweets
# count = 653
# found 90 tweets
# found 9 tweets
# found 0 tweets
# no tweets found
# count = 654
# found 87 tweets
# found 9 tweets
# found 2 tweets
# found 1 tweets
# found 1 tweets
# count = 655
# found 87 tweets
# found 10 tweets
# found 3 tweets
# count = 656
# found 89 tweets
# found 10 tweets
# found 1 tweets
# count = 657
# found 90 tweets
# found 9 tweets
# found 0 tweets
# no tweets found
# count = 658
# found 84 tweets
# found 14 tweets
# found 1 tweets
# found 1 tweets
# count = 659
# found 87 tweets
# found 13 tweets
# count = 660
# found 93 tweets
# found 6 tweets
# found 1 tweets
# count = 661
# found 90 tweets
# found 6 tweets
# found 0 tweets
# no tweets found
# count = 662
# found 94 tweets
# found 6 tweets
# count = 663
# found 89 tweets
# found 11 tweets
# count = 664
# found 90 tweets
# found 9 tweets
# found 1 tweets
# count = 665
# found 92 tweets
# found 8 tweets
# count = 666
# found 87 tweets
# found 13 tweets
# count = 667
# found 87 tweets
# found 11 tweets
# found 1 tweets
# found 1 tweets
# count = 668
# found 83 tweets
# found 15 tweets
# found 2 tweets
# count = 669
# found 86 tweets
# found 13 tweets
# found 0 tweets
# no tweets found
# count = 670
# found 86 tweets
# found 8 tweets
# found 6 tweets
# count = 671
# found 92 tweets
# found 6 tweets
# found 2 tweets
# count = 672
# found 86 tweets
# found 8 tweets
# found 6 tweets
# count = 673
# found 94 tweets
# found 6 tweets
# count = 674
# found 97 tweets
# found 2 tweets
# found 1 tweets
# count = 675
# found 100 tweets
# count = 676
# found 93 tweets
# found 3 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 677
# found 84 tweets
# found 12 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 678
# found 90 tweets
# found 9 tweets
# found 0 tweets
# no tweets found
# count = 679
# found 82 tweets
# found 15 tweets
# found 3 tweets
# count = 680
# found 98 tweets
# found 2 tweets
# count = 681
# found 96 tweets
# found 2 tweets
# found 1 tweets
# found 1 tweets
# count = 682
# found 88 tweets
# found 6 tweets
# found 5 tweets
# found 1 tweets
# count = 683
# found 89 tweets
# found 11 tweets
# count = 684
# found 89 tweets
# found 8 tweets
# found 1 tweets
# found 1 tweets
# found 1 tweets
# count = 685
# found 92 tweets
# found 8 tweets
# count = 686
# found 90 tweets
# found 10 tweets
# count = 687
# found 90 tweets
# found 8 tweets
# found 0 tweets
# no tweets found
# count = 688
# found 85 tweets
# found 15 tweets
# count = 689
# found 88 tweets
# found 10 tweets
# found 0 tweets
# no tweets found
# count = 690
# found 89 tweets
# found 10 tweets
# found 1 tweets
# count = 691
# found 89 tweets
# found 8 tweets
# found 1 tweets
# found 2 tweets
# count = 692
# found 79 tweets
# found 17 tweets
# found 3 tweets
# found 1 tweets
# count = 693
# found 97 tweets
# found 3 tweets
# count = 694
# found 82 tweets
# found 15 tweets
# found 1 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 695
# found 90 tweets
# found 6 tweets
# found 4 tweets
# count = 696
# found 96 tweets
# found 4 tweets
# count = 697
# found 88 tweets
# found 11 tweets
# found 1 tweets
# count = 698
# found 90 tweets
# found 7 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 699
# found 90 tweets
# found 9 tweets
# found 1 tweets
# count = 700
# found 87 tweets
# found 13 tweets
# count = 701
# found 95 tweets
# found 5 tweets
# count = 702
# found 96 tweets
# found 2 tweets
# found 1 tweets
# exception raised, waiting 15 minutes
# (until: 2019-03-28 13:34:52.792199 )
# count = 703
# found 95 tweets
# found 5 tweets
# count = 704
# found 94 tweets
# found 4 tweets
# found 1 tweets
# found 1 tweets
# count = 705
# found 94 tweets
# found 4 tweets
# found 0 tweets
# no tweets found
# count = 706
# found 91 tweets
# found 8 tweets
# found 1 tweets
# count = 707
# found 91 tweets
# found 8 tweets
# found 1 tweets
# count = 708
# found 93 tweets
# found 6 tweets
# found 0 tweets
# no tweets found
# count = 709
# found 91 tweets
# found 9 tweets
# count = 710
# found 94 tweets
# found 6 tweets
# count = 711
# found 91 tweets
# found 9 tweets
# count = 712
# found 91 tweets
# found 8 tweets
# found 1 tweets
# count = 713
# found 93 tweets
# found 7 tweets
# count = 714
# found 87 tweets
# found 11 tweets
# found 0 tweets
# no tweets found
# count = 715
# found 91 tweets
# found 7 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 716
# found 93 tweets
# found 5 tweets
# found 1 tweets
# found 1 tweets
# count = 717
# found 88 tweets
# found 10 tweets
# found 1 tweets
# found 1 tweets
# count = 718
# found 96 tweets
# found 4 tweets
# count = 719
# found 90 tweets
# found 10 tweets
# count = 720
# found 91 tweets
# found 9 tweets
# count = 721
# found 91 tweets
# found 8 tweets
# found 1 tweets
# count = 722
# found 92 tweets
# found 5 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 723
# found 83 tweets
# found 16 tweets
# found 0 tweets
# no tweets found
# count = 724
# found 82 tweets
# found 16 tweets
# found 2 tweets
# count = 725
# found 94 tweets
# found 4 tweets
# found 0 tweets
# no tweets found
# count = 726
# found 91 tweets
# found 9 tweets
# count = 727
# found 93 tweets
# found 5 tweets
# found 2 tweets
# count = 728
# found 88 tweets
# found 7 tweets
# found 4 tweets
# found 1 tweets
# count = 729
# found 86 tweets
# found 11 tweets
# found 3 tweets
# count = 730
# found 81 tweets
# found 15 tweets
# found 3 tweets
# found 0 tweets
# ...
# found 93 tweets
# found 7 tweets
# count = 1219
# found 94 tweets
# found 5 tweets
# found 1 tweets
# count = 1220
# found 85 tweets
# found 14 tweets
# found 0 tweets
# no tweets found
# count = 1221
# found 77 tweets
# found 22 tweets
# found 0 tweets
# no tweets found
# count = 1222
# found 92 tweets
# found 5 tweets
# found 2 tweets
# exception raised, waiting 15 minutes
# (until: 2019-03-28 16:44:56.223588 )
# count = 1223
# found 85 tweets
# found 12 tweets
# found 1 tweets
# found 1 tweets
# found 1 tweets
# count = 1224
# found 91 tweets
# found 9 tweets
# count = 1225
# found 94 tweets
# found 4 tweets
# found 2 tweets
# count = 1226
# found 89 tweets
# found 7 tweets
# found 4 tweets
# count = 1227
# found 90 tweets
# found 9 tweets
# found 0 tweets
# no tweets found
# count = 1228
# found 90 tweets
# found 10 tweets
# count = 1229
# found 90 tweets
# found 9 tweets
# found 0 tweets
# no tweets found
# count = 1230
# found 85 tweets
# found 14 tweets
# found 0 tweets
# no tweets found
# count = 1231
# found 80 tweets
# found 20 tweets
# count = 1232
# found 89 tweets
# found 11 tweets
# count = 1233
# found 80 tweets
# found 15 tweets
# found 5 tweets
# count = 1234
# found 76 tweets
# found 22 tweets
# found 2 tweets
# count = 1235
# found 89 tweets
# found 9 tweets
# found 0 tweets
# no tweets found
# count = 1236
# found 81 tweets
# found 17 tweets
# found 2 tweets
# count = 1237
# found 85 tweets
# found 12 tweets
# found 3 tweets
# count = 1238
# found 95 tweets
# found 5 tweets
# count = 1239
# found 86 tweets
# found 9 tweets
# found 4 tweets
# found 0 tweets
# no tweets found
# count = 1240
# found 95 tweets
# found 5 tweets
# count = 1241
# found 80 tweets
# found 16 tweets
# found 3 tweets
# found 1 tweets
# count = 1242
# found 88 tweets
# found 8 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 1243
# found 93 tweets
# found 4 tweets
# found 2 tweets
# found 1 tweets
# count = 1244
# found 86 tweets
# found 13 tweets
# found 1 tweets
# count = 1245
# found 77 tweets
# found 20 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 1246
# found 93 tweets
# found 6 tweets
# found 0 tweets
# no tweets found
# count = 1247
# found 87 tweets
# found 8 tweets
# found 4 tweets
# found 1 tweets
# count = 1248
# found 86 tweets
# found 12 tweets
# found 2 tweets
# count = 1249
# found 85 tweets
# found 13 tweets
# found 0 tweets
# no tweets found
# count = 1250
# found 85 tweets
# found 12 tweets
# found 3 tweets
# count = 1251
# found 85 tweets
# found 9 tweets
# found 1 tweets
# found 3 tweets
# found 1 tweets
# found 1 tweets
# count = 1252
# found 84 tweets
# found 9 tweets
# found 7 tweets
# count = 1253
# found 89 tweets
# found 9 tweets
# found 2 tweets
# count = 1254
# found 85 tweets
# found 11 tweets
# found 3 tweets
# found 1 tweets
# count = 1255
# found 90 tweets
# found 7 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 1256
# found 78 tweets
# found 14 tweets
# found 7 tweets
# found 1 tweets
# count = 1257
# found 79 tweets
# found 17 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 1258
# found 88 tweets
# found 8 tweets
# found 4 tweets
# count = 1259
# found 99 tweets
# found 1 tweets
# count = 1260
# found 100 tweets
# count = 1261
# found 91 tweets
# found 8 tweets
# found 1 tweets
# count = 1262
# found 100 tweets
# count = 1263
# found 93 tweets
# found 5 tweets
# found 2 tweets
# count = 1264
# found 92 tweets
# found 7 tweets
# found 1 tweets
# count = 1265
# found 92 tweets
# found 7 tweets
# found 1 tweets
# count = 1266
# found 97 tweets
# found 3 tweets
# count = 1267
# found 90 tweets
# found 10 tweets
# count = 1268
# found 95 tweets
# found 3 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 1269
# found 91 tweets
# found 8 tweets
# found 0 tweets
# no tweets found
# count = 1270
# found 91 tweets
# found 8 tweets
# found 0 tweets
# no tweets found
# count = 1271
# found 89 tweets
# found 8 tweets
# found 2 tweets
# found 1 tweets
# count = 1272
# found 94 tweets
# found 5 tweets
# found 0 tweets
# no tweets found
# count = 1273
# found 88 tweets
# found 11 tweets
# found 1 tweets
# count = 1274
# found 86 tweets
# found 14 tweets
# count = 1275
# found 89 tweets
# found 10 tweets
# found 0 tweets
# no tweets found
# count = 1276
# found 90 tweets
# found 8 tweets
# found 0 tweets
# no tweets found
# count = 1277
# found 86 tweets
# found 11 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 1278
# found 83 tweets
# found 10 tweets
# found 6 tweets
# found 0 tweets
# no tweets found
# count = 1279
# found 96 tweets
# found 4 tweets
# count = 1280
# found 82 tweets
# found 16 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 1281
# found 91 tweets
# exception raised, waiting 15 minutes
# (until: 2019-03-28 17:02:08.506903 )
# count = 1282
# found 90 tweets
# found 8 tweets
# found 2 tweets
# count = 1283
# found 89 tweets
# found 6 tweets
# found 5 tweets
# count = 1284
# found 86 tweets
# found 11 tweets
# found 2 tweets
# found 1 tweets
# count = 1285
# found 94 tweets
# found 3 tweets
# found 3 tweets
# count = 1286
# found 90 tweets
# found 7 tweets
# found 0 tweets
# no tweets found
# count = 1287
# found 94 tweets
# found 4 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 1288
# found 84 tweets
# found 13 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 1289
# found 92 tweets
# found 7 tweets
# found 0 tweets
# no tweets found
# count = 1290
# found 88 tweets
# found 9 tweets
# found 1 tweets
# found 2 tweets
# count = 1291
# found 83 tweets
# found 17 tweets
# count = 1292
# found 92 tweets
# found 6 tweets
# found 2 tweets
# count = 1293
# found 95 tweets
# found 5 tweets
# count = 1294
# found 83 tweets
# found 14 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 1295
# found 96 tweets
# found 3 tweets
# found 1 tweets
# count = 1296
# found 96 tweets
# found 3 tweets
# found 1 tweets
# count = 1297
# found 92 tweets
# found 5 tweets
# found 1 tweets
# found 2 tweets
# count = 1298
# found 88 tweets
# found 8 tweets
# found 0 tweets
# no tweets found
# count = 1299
# found 85 tweets
# found 11 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 1300
# found 87 tweets
# found 13 tweets
# count = 1301
# found 84 tweets
# found 16 tweets
# count = 1302
# found 92 tweets
# found 4 tweets
# found 2 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 1303
# found 90 tweets
# found 7 tweets
# found 2 tweets
# found 1 tweets
# count = 1304
# found 91 tweets
# found 7 tweets
# found 0 tweets
# no tweets found
# count = 1305
# found 98 tweets
# found 1 tweets
# found 1 tweets
# count = 1306
# found 90 tweets
# found 10 tweets
# count = 1307
# found 94 tweets
# found 4 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 1308
# found 84 tweets
# found 14 tweets
# found 2 tweets
# count = 1309
# found 87 tweets
# found 9 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 1310
# found 94 tweets
# found 4 tweets
# found 2 tweets
# count = 1311
# found 88 tweets
# found 8 tweets
# found 2 tweets
# found 2 tweets
# count = 1312
# found 88 tweets
# found 9 tweets
# found 3 tweets
# count = 1313
# found 92 tweets
# found 5 tweets
# found 3 tweets
# count = 1314
# found 94 tweets
# found 4 tweets
# found 2 tweets
# count = 1315
# found 85 tweets
# found 10 tweets
# found 5 tweets
# count = 1316
# found 84 tweets
# found 12 tweets
# found 3 tweets
# found 1 tweets
# count = 1317
# found 88 tweets
# found 9 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 1318
# found 80 tweets
# found 18 tweets
# found 2 tweets
# count = 1319
# found 87 tweets
# found 7 tweets
# found 6 tweets
# count = 1320
# found 92 tweets
# found 7 tweets
# found 0 tweets
# no tweets found
# count = 1321
# found 86 tweets
# found 9 tweets
# found 0 tweets
# no tweets found
# count = 1322
# found 84 tweets
# found 16 tweets
# count = 1323
# found 100 tweets
# count = 1324
# found 86 tweets
# found 11 tweets
# found 3 tweets
# count = 1325
# found 91 tweets
# found 4 tweets
# found 4 tweets
# found 1 tweets
# count = 1326
# found 90 tweets
# found 10 tweets
# count = 1327
# found 89 tweets
# found 11 tweets
# count = 1328
# found 90 tweets
# found 8 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 1329
# found 86 tweets
# found 14 tweets
# count = 1330
# found 82 tweets
# found 17 tweets
# found 1 tweets
# count = 1331
# found 85 tweets
# found 11 tweets
# found 2 tweets
# found 1 tweets
# found 1 tweets
# count = 1332
# found 91 tweets
# found 8 tweets
# found 0 tweets
# no tweets found
# count = 1333
# found 89 tweets
# found 9 tweets
# found 2 tweets
# count = 1334
# found 86 tweets
# found 11 tweets
# found 3 tweets
# count = 1335
# found 98 tweets
# found 1 tweets
# found 1 tweets
# count = 1336
# found 76 tweets
# found 18 tweets
# found 5 tweets
# found 1 tweets
# count = 1337
# found 92 tweets
# found 7 tweets
# found 0 tweets
# no tweets found
# count = 1338
# found 91 tweets
# found 7 tweets
# found 2 tweets
# count = 1339
# exception raised, waiting 15 minutes
# (until: 2019-03-28 17:19:08.434717 )
# count = 1340
# found 82 tweets
# found 17 tweets
# found 1 tweets
# count = 1341
# found 89 tweets
# found 10 tweets
# found 0 tweets
# no tweets found
# count = 1342
# found 88 tweets
# found 9 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 1343
# found 99 tweets
# found 0 tweets
# no tweets found
# count = 1344
# found 93 tweets
# found 6 tweets
# found 0 tweets
# no tweets found
# count = 1345
# found 87 tweets
# found 11 tweets
# found 2 tweets
# count = 1346
# found 93 tweets
# found 4 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 1347
# found 85 tweets
# found 15 tweets
# count = 1348
# found 96 tweets
# found 1 tweets
# found 1 tweets
# found 1 tweets
# found 1 tweets
# count = 1349
# found 96 tweets
# found 3 tweets
# found 1 tweets
# count = 1350
# found 94 tweets
# found 6 tweets
# count = 1351
# found 87 tweets
# found 9 tweets
# found 3 tweets
# found 1 tweets
# count = 1352
# found 92 tweets
# found 7 tweets
# found 1 tweets
# count = 1353
# found 92 tweets
# found 3 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 1354
# found 85 tweets
# found 11 tweets
# found 4 tweets
# count = 1355
# found 94 tweets
# found 6 tweets
# count = 1356
# found 86 tweets
# found 10 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 1357
# found 87 tweets
# found 11 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 1358
# found 79 tweets
# found 19 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 1359
# found 85 tweets
# found 15 tweets
# count = 1360
# found 84 tweets
# found 12 tweets
# found 1 tweets
# found 1 tweets
# found 1 tweets
# found 1 tweets
# count = 1361
# found 76 tweets
# found 19 tweets
# found 4 tweets
# found 1 tweets
# count = 1362
# found 81 tweets
# found 13 tweets
# found 5 tweets
# found 0 tweets
# no tweets found
# count = 1363
# found 96 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 1364
# found 95 tweets
# found 5 tweets
# count = 1365
# found 88 tweets
# found 11 tweets
# found 1 tweets
# count = 1366
# found 90 tweets
# found 10 tweets
# count = 1367
# found 89 tweets
# found 7 tweets
# found 2 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 1368
# found 89 tweets
# found 10 tweets
# found 1 tweets
# count = 1369
# found 88 tweets
# found 10 tweets
# found 1 tweets
# found 1 tweets
# count = 1370
# found 87 tweets
# found 12 tweets
# found 1 tweets
# count = 1371
# found 87 tweets
# found 10 tweets
# found 2 tweets
# found 1 tweets
# count = 1372
# found 88 tweets
# found 12 tweets
# count = 1373
# found 94 tweets
# found 4 tweets
# found 1 tweets
# found 1 tweets
# count = 1374
# found 99 tweets
# found 1 tweets
# count = 1375
# found 91 tweets
# found 7 tweets
# found 2 tweets
# count = 1376
# found 96 tweets
# found 4 tweets
# count = 1377
# found 96 tweets
# found 3 tweets
# found 1 tweets
# count = 1378
# found 94 tweets
# found 5 tweets
# found 0 tweets
# no tweets found
# count = 1379
# found 90 tweets
# found 10 tweets
# count = 1380
# found 88 tweets
# found 11 tweets
# found 0 tweets
# no tweets found
# count = 1381
# found 98 tweets
# found 0 tweets
# no tweets found
# count = 1382
# found 92 tweets
# found 8 tweets
# count = 1383
# found 95 tweets
# found 4 tweets
# found 0 tweets
# no tweets found
# count = 1384
# found 98 tweets
# found 1 tweets
# found 1 tweets
# count = 1385
# found 90 tweets
# found 7 tweets
# found 0 tweets
# no tweets found
# count = 1386
# found 83 tweets
# found 11 tweets
# found 6 tweets
# count = 1387
# found 97 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 1388
# found 80 tweets
# found 18 tweets
# found 2 tweets
# count = 1389
# found 90 tweets
# found 10 tweets
# count = 1390
# found 85 tweets
# found 12 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 1391
# found 90 tweets
# found 7 tweets
# found 1 tweets
# found 2 tweets
# count = 1392
# found 82 tweets
# found 11 tweets
# found 6 tweets
# found 1 tweets
# count = 1393
# found 87 tweets
# found 11 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 1394
# found 77 tweets
# found 19 tweets
# found 2 tweets
# found 1 tweets
# found 1 tweets
# count = 1395
# found 88 tweets
# found 8 tweets
# found 2 tweets
# found 2 tweets
# count = 1396
# exception raised, waiting 15 minutes
# (until: 2019-03-28 17:36:06.311600 )
# count = 1397
# found 85 tweets
# found 9 tweets
# found 5 tweets
# found 1 tweets
# count = 1398
# found 98 tweets
# found 2 tweets
# count = 1399
# found 88 tweets
# found 12 tweets
# count = 1400
# found 86 tweets
# found 12 tweets
# found 2 tweets
# count = 1401
# found 85 tweets
# found 13 tweets
# found 2 tweets
# count = 1402
# found 87 tweets
# found 10 tweets
# found 2 tweets
# found 1 tweets
# count = 1403
# found 86 tweets
# found 13 tweets
# found 0 tweets
# no tweets found
# count = 1404
# found 90 tweets
# found 10 tweets
# count = 1405
# found 87 tweets
# found 13 tweets
# count = 1406
# found 83 tweets
# found 17 tweets
# count = 1407
# found 84 tweets
# found 12 tweets
# found 3 tweets
# found 1 tweets
# count = 1408
# found 87 tweets
# found 9 tweets
# found 2 tweets
# found 2 tweets
# count = 1409
# found 83 tweets
# found 14 tweets
# found 1 tweets
# found 2 tweets
# count = 1410
# found 86 tweets
# found 13 tweets
# found 0 tweets
# no tweets found
# count = 1411
# found 94 tweets
# found 6 tweets
# count = 1412
# found 88 tweets
# found 12 tweets
# count = 1413
# found 84 tweets
# found 12 tweets
# found 3 tweets
# found 1 tweets
# count = 1414
# found 89 tweets
# found 7 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 1415
# found 91 tweets
# found 6 tweets
# found 0 tweets
# no tweets found
# count = 1416
# found 94 tweets
# found 6 tweets
# count = 1417
# found 91 tweets
# found 7 tweets
# found 2 tweets
# count = 1418
# found 91 tweets
# found 6 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 1419
# found 86 tweets
# found 12 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 1420
# found 86 tweets
# found 12 tweets
# found 2 tweets
# count = 1421
# found 86 tweets
# found 11 tweets
# found 2 tweets
# found 1 tweets
# count = 1422
# found 84 tweets
# found 13 tweets
# found 2 tweets
# found 1 tweets
# count = 1423
# found 83 tweets
# found 17 tweets
# count = 1424
# found 89 tweets
# found 10 tweets
# found 1 tweets
# count = 1425
# found 85 tweets
# found 12 tweets
# found 3 tweets
# count = 1426
# found 84 tweets
# found 14 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 1427
# found 95 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 1428
# found 85 tweets
# found 13 tweets
# found 2 tweets
# count = 1429
# found 88 tweets
# found 9 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 1430
# found 89 tweets
# found 10 tweets
# found 1 tweets
# count = 1431
# found 88 tweets
# found 10 tweets
# found 2 tweets
# count = 1432
# found 91 tweets
# found 4 tweets
# found 5 tweets
# count = 1433
# found 94 tweets
# found 6 tweets
# count = 1434
# found 89 tweets
# found 9 tweets
# found 2 tweets
# count = 1435
# found 80 tweets
# found 19 tweets
# found 1 tweets
# count = 1436
# found 87 tweets
# found 10 tweets
# found 2 tweets
# found 0 tweets
# no tweets found
# count = 1437
# found 80 tweets
# found 14 tweets
# found 5 tweets
# found 0 tweets
# no tweets found
# count = 1438
# found 95 tweets
# found 3 tweets
# found 0 tweets
# no tweets found
# count = 1439
# found 79 tweets
# found 21 tweets
# count = 1440
# found 98 tweets
# found 2 tweets
# count = 1441
# found 89 tweets
# found 8 tweets
# found 2 tweets
# found 1 tweets
# count = 1442
# found 92 tweets
# found 7 tweets
# found 0 tweets
# no tweets found
# count = 1443
# found 89 tweets
# found 10 tweets
# found 1 tweets
# count = 1444
# found 94 tweets
# found 6 tweets
# count = 1445
# found 84 tweets
# found 12 tweets
# found 2 tweets
# found 1 tweets
# found 0 tweets
# no tweets found
# count = 1446
# found 89 tweets
# found 11 tweets
# count = 1447
# found 87 tweets
# found 8 tweets
# found 2 tweets
# found 3 tweets
# count = 1448
# found 91 tweets
# found 6 tweets
# found 3 tweets
# count = 1449
# found 92 tweets
# found 3 tweets
# found 4 tweets
# found 1 tweets
# count = 1450
# found 92 tweets
# found 6 tweets
# found 0 tweets
# no tweets found
# count = 1451
# found 95 tweets
# found 5 tweets
# count = 1452
# found 81 tweets
# found 18 tweets
# found 1 tweets
# count = 1453
# found 90 tweets
# found 9 tweets
# found 1 tweets
# count = 1454
# found 90 tweets
# found 9 tweets
# found 1 tweets
# count = 1455
# found 94 tweets
# exception raised, waiting 15 minutes
# (until: 2019-03-28 17:53:22.518350 )
